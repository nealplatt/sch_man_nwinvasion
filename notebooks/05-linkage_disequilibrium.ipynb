# %% [markdown]
# # Genomic analysis of a parasite invasion: colonization of the New World by the blood fluke, Schistosoma mansoni
#
# Roy Nelson Platt II*, Frédéric D. Chevalier*, Winka Le Clec'h, Marina McDew-White, Philip T. LoVerde, Rafael Ramiro de Assis, Guilherme Oliveira, Safari Kinunghi, Anouk Gouvras, Bonnie Webster, Joanne Webster, Aidan Emery, David Rollinson, Timothy J. Anderson
#
# # Finding regions under selection
#
# use the `sch_man_nwinvasion-ld` conda env

# %%
import os
import shutil
import vcf
import re
import gzip
import pandas as pd
import yaml
import subprocess
import matplotlib.pyplot as plt
from scipy import stats
from collections import defaultdict
import numpy as np
#from IPython.display import Image
#from Bio import SeqIO
from scipy.interpolate import interp1d
from statsmodels.nonparametric.smoothers_lowess import lowess


#import rpy2.ipython


#%load_ext rpy2.ipython

os.chdir("/master/nplatt/sch_man_nwinvasion")

# %% [markdown]
# # Linkage Disequilibrium

# %%
if not os.path.isdir("results/ld"):
    os.mkdir("results/ld")

# %% [markdown]
# Read in population assignment and create (new) list files

# %%
with open('data/pop_assign.yml') as yaml_file:
    pop_assign = yaml.load(yaml_file, Loader=yaml.FullLoader)

for pop in set(pop_assign.values()):
    list_file = "results/ld/{}.list".format(pop);
    if os.path.exists(list_file):
        os.remove(list_file)

# %%
for pop in set(pop_assign.values()):
    list_file = "results/ld/{}.list".format(pop);
    if os.path.exists(list_file):
        os.remove(list_file)
    
for sample in pop_assign:
   
    pop=pop_assign[sample]
    list_file="results/ld/" + pop + ".list"
    with open(list_file, 'a') as filehandle:
        filehandle.write("{}\n".format(sample))

# %% [markdown]
# ## Calculate R2 with VCFtools and Plink

# %%
in_vcf="results/variant_filtration/smv7_ex_autosomes.vcf"

for pop in ["senegal", "niger", "brazil", "tanzania"]:
    print(pop)
    in_list = "results/ld/{}.list".format(pop)
    
    for chrom in list(range(1, 8)):
        chrom="SM_V7_{}".format(chrom)
        out_vcf = "results/ld/smv7_ex_autosomes_{}_{}.vcf".format(pop, chrom)
        
        #get ld chrom vcf
        vcf_cmd="vcftools --vcf {} --maf 0.05 --chr {} --keep {} --recode --recode-INFO-all --stdout >{}".format(in_vcf, chrom, in_list, out_vcf)
        # !{vcf_cmd}

        #convert vcf to plink
        plink_prefix="results/ld/smv7_ex_autosomes_{}_{}".format(pop, chrom)
        plink_cmd="plink --threads 6 --vcf {} --out {} --double-id --recode12 --allow-extra-chr".format(out_vcf, plink_prefix)
        # !{plink_cmd}  
        
        #calculate R2 between all snps on a chr
        plink_cmd="plink --threads 6 --r2 --file {} --out {} --double-id --allow-extra-chr --ld-window-r2 0.0 --ld-window 1000000 --ld-window-kb 1000".format(plink_prefix, plink_prefix)
        # !{plink_cmd}
# Out:
# senegal
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Note: --recode12 flag deprecated.  Use "--recode 12 ...".
# Logging to results/ld/smv7_ex_autosomes_senegal_SM_V7_1.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --out results/ld/smv7_ex_autosomes_senegal_SM_V7_1
#   --recode 12
#   --threads 6
#   --vcf results/ld/smv7_ex_autosomes_senegal_SM_V7_1.vcf
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# --vcf: results/ld/smv7_ex_autosomes_senegal_SM_V7_1-temporary.bed +
# results/ld/smv7_ex_autosomes_senegal_SM_V7_1-temporary.bim +
# results/ld/smv7_ex_autosomes_senegal_SM_V7_1-temporary.fam written.
# 2680 variants loaded from .bim file.
# 25 people (0 males, 0 females, 25 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to results/ld/smv7_ex_autosomes_senegal_SM_V7_1.nosex
# .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 25 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.884567.
# 2680 variants and 25 people pass filters and QC.
# Note: No phenotypes present.
# --recode ped to results/ld/smv7_ex_autosomes_senegal_SM_V7_1.ped +
# results/ld/smv7_ex_autosomes_senegal_SM_V7_1.map ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to results/ld/smv7_ex_autosomes_senegal_SM_V7_1.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --file results/ld/smv7_ex_autosomes_senegal_SM_V7_1
#   --ld-window 1000000
#   --ld-window-kb 1000
#   --ld-window-r2 0.0
#   --out results/ld/smv7_ex_autosomes_senegal_SM_V7_1
#   --r2
#   --threads 6
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# .ped scan complete (for binary autoconversion).0646872768084889296100%
# Performing single-pass .bed write (2680 variants, 25 people).
# --file: results/ld/smv7_ex_autosomes_senegal_SM_V7_1-temporary.bed +444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394%
# results/ld/smv7_ex_autosomes_senegal_SM_V7_1-temporary.bim +
# results/ld/smv7_ex_autosomes_senegal_SM_V7_1-temporary.fam written.
# 2680 variants loaded from .bim file.
# 25 people (0 males, 0 females, 25 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to results/ld/smv7_ex_autosomes_senegal_SM_V7_1.nosex
# .
# Using up to 6 threads (change this with --threads).
# Before main variant filters, 25 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.884567.
# 2680 variants and 25 people pass filters and QC.
# Note: No phenotypes present.
# --r2 to results/ld/smv7_ex_autosomes_senegal_SM_V7_1.ld ... 0% [processingwriting]        done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Note: --recode12 flag deprecated.  Use "--recode 12 ...".
# Logging to results/ld/smv7_ex_autosomes_senegal_SM_V7_2.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --out results/ld/smv7_ex_autosomes_senegal_SM_V7_2
#   --recode 12
#   --threads 6
#   --vcf results/ld/smv7_ex_autosomes_senegal_SM_V7_2.vcf
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# --vcf: results/ld/smv7_ex_autosomes_senegal_SM_V7_2-temporary.bed +
# results/ld/smv7_ex_autosomes_senegal_SM_V7_2-temporary.bim +
# results/ld/smv7_ex_autosomes_senegal_SM_V7_2-temporary.fam written.
# 4196 variants loaded from .bim file.
# 25 people (0 males, 0 females, 25 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to results/ld/smv7_ex_autosomes_senegal_SM_V7_2.nosex
# .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 25 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.868503.
# 4196 variants and 25 people pass filters and QC.
# Note: No phenotypes present.
# --recode ped to results/ld/smv7_ex_autosomes_senegal_SM_V7_2.ped +
# results/ld/smv7_ex_autosomes_senegal_SM_V7_2.map ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to results/ld/smv7_ex_autosomes_senegal_SM_V7_2.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --file results/ld/smv7_ex_autosomes_senegal_SM_V7_2
#   --ld-window 1000000
#   --ld-window-kb 1000
#   --ld-window-r2 0.0
#   --out results/ld/smv7_ex_autosomes_senegal_SM_V7_2
#   --r2
#   --threads 6
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# .ped scan complete (for binary autoconversion).0646872768084889296100%
# Performing single-pass .bed write (4196 variants, 25 people).
# --file: results/ld/smv7_ex_autosomes_senegal_SM_V7_2-temporary.bed +444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394%
# results/ld/smv7_ex_autosomes_senegal_SM_V7_2-temporary.bim +
# results/ld/smv7_ex_autosomes_senegal_SM_V7_2-temporary.fam written.
# 4196 variants loaded from .bim file.
# 25 people (0 males, 0 females, 25 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to results/ld/smv7_ex_autosomes_senegal_SM_V7_2.nosex
# .
# Using up to 6 threads (change this with --threads).
# Before main variant filters, 25 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.868503.
# 4196 variants and 25 people pass filters and QC.
# Note: No phenotypes present.
# --r2 to results/ld/smv7_ex_autosomes_senegal_SM_V7_2.ld ... 0% [processingwriting]        done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Note: --recode12 flag deprecated.  Use "--recode 12 ...".
# Logging to results/ld/smv7_ex_autosomes_senegal_SM_V7_3.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --out results/ld/smv7_ex_autosomes_senegal_SM_V7_3
#   --recode 12
#   --threads 6
#   --vcf results/ld/smv7_ex_autosomes_senegal_SM_V7_3.vcf
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# --vcf: results/ld/smv7_ex_autosomes_senegal_SM_V7_3-temporary.bed +
# results/ld/smv7_ex_autosomes_senegal_SM_V7_3-temporary.bim +
# results/ld/smv7_ex_autosomes_senegal_SM_V7_3-temporary.fam written.
# 3071 variants loaded from .bim file.
# 25 people (0 males, 0 females, 25 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to results/ld/smv7_ex_autosomes_senegal_SM_V7_3.nosex
# .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 25 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.869385.
# 3071 variants and 25 people pass filters and QC.
# Note: No phenotypes present.
# --recode ped to results/ld/smv7_ex_autosomes_senegal_SM_V7_3.ped +
# results/ld/smv7_ex_autosomes_senegal_SM_V7_3.map ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to results/ld/smv7_ex_autosomes_senegal_SM_V7_3.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --file results/ld/smv7_ex_autosomes_senegal_SM_V7_3
#   --ld-window 1000000
#   --ld-window-kb 1000
#   --ld-window-r2 0.0
#   --out results/ld/smv7_ex_autosomes_senegal_SM_V7_3
#   --r2
#   --threads 6
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# .ped scan complete (for binary autoconversion).0646872768084889296100%
# Performing single-pass .bed write (3071 variants, 25 people).
# --file: results/ld/smv7_ex_autosomes_senegal_SM_V7_3-temporary.bed +444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394%
# results/ld/smv7_ex_autosomes_senegal_SM_V7_3-temporary.bim +
# results/ld/smv7_ex_autosomes_senegal_SM_V7_3-temporary.fam written.
# 3071 variants loaded from .bim file.
# 25 people (0 males, 0 females, 25 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to results/ld/smv7_ex_autosomes_senegal_SM_V7_3.nosex
# .
# Using up to 6 threads (change this with --threads).
# Before main variant filters, 25 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.869385.
# 3071 variants and 25 people pass filters and QC.
# Note: No phenotypes present.
# --r2 to results/ld/smv7_ex_autosomes_senegal_SM_V7_3.ld ... 0% [processingwriting]        done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Note: --recode12 flag deprecated.  Use "--recode 12 ...".
# Logging to results/ld/smv7_ex_autosomes_senegal_SM_V7_4.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --out results/ld/smv7_ex_autosomes_senegal_SM_V7_4
#   --recode 12
#   --threads 6
#   --vcf results/ld/smv7_ex_autosomes_senegal_SM_V7_4.vcf
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# --vcf: results/ld/smv7_ex_autosomes_senegal_SM_V7_4-temporary.bed +
# results/ld/smv7_ex_autosomes_senegal_SM_V7_4-temporary.bim +
# results/ld/smv7_ex_autosomes_senegal_SM_V7_4-temporary.fam written.
# 1700 variants loaded from .bim file.
# 25 people (0 males, 0 females, 25 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to results/ld/smv7_ex_autosomes_senegal_SM_V7_4.nosex
# .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 25 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.864494.
# 1700 variants and 25 people pass filters and QC.
# Note: No phenotypes present.
# --recode ped to results/ld/smv7_ex_autosomes_senegal_SM_V7_4.ped +
# results/ld/smv7_ex_autosomes_senegal_SM_V7_4.map ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to results/ld/smv7_ex_autosomes_senegal_SM_V7_4.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --file results/ld/smv7_ex_autosomes_senegal_SM_V7_4
#   --ld-window 1000000
#   --ld-window-kb 1000
#   --ld-window-r2 0.0
#   --out results/ld/smv7_ex_autosomes_senegal_SM_V7_4
#   --r2
#   --threads 6
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# .ped scan complete (for binary autoconversion).0646872768084889296100%
# Performing single-pass .bed write (1700 variants, 25 people).
# --file: results/ld/smv7_ex_autosomes_senegal_SM_V7_4-temporary.bed +444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394%
# results/ld/smv7_ex_autosomes_senegal_SM_V7_4-temporary.bim +
# results/ld/smv7_ex_autosomes_senegal_SM_V7_4-temporary.fam written.
# 1700 variants loaded from .bim file.
# 25 people (0 males, 0 females, 25 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to results/ld/smv7_ex_autosomes_senegal_SM_V7_4.nosex
# .
# Using up to 6 threads (change this with --threads).
# Before main variant filters, 25 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.864494.
# 1700 variants and 25 people pass filters and QC.
# Note: No phenotypes present.
# --r2 to results/ld/smv7_ex_autosomes_senegal_SM_V7_4.ld ... 0% [processingwriting]        done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Note: --recode12 flag deprecated.  Use "--recode 12 ...".
# Logging to results/ld/smv7_ex_autosomes_senegal_SM_V7_5.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --out results/ld/smv7_ex_autosomes_senegal_SM_V7_5
#   --recode 12
#   --threads 6
#   --vcf results/ld/smv7_ex_autosomes_senegal_SM_V7_5.vcf
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# --vcf: results/ld/smv7_ex_autosomes_senegal_SM_V7_5-temporary.bed +
# results/ld/smv7_ex_autosomes_senegal_SM_V7_5-temporary.bim +
# results/ld/smv7_ex_autosomes_senegal_SM_V7_5-temporary.fam written.
# 1177 variants loaded from .bim file.
# 25 people (0 males, 0 females, 25 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to results/ld/smv7_ex_autosomes_senegal_SM_V7_5.nosex
# .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 25 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.851215.
# 1177 variants and 25 people pass filters and QC.
# Note: No phenotypes present.
# --recode ped to results/ld/smv7_ex_autosomes_senegal_SM_V7_5.ped +
# results/ld/smv7_ex_autosomes_senegal_SM_V7_5.map ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to results/ld/smv7_ex_autosomes_senegal_SM_V7_5.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --file results/ld/smv7_ex_autosomes_senegal_SM_V7_5
#   --ld-window 1000000
#   --ld-window-kb 1000
#   --ld-window-r2 0.0
#   --out results/ld/smv7_ex_autosomes_senegal_SM_V7_5
#   --r2
#   --threads 6
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# .ped scan complete (for binary autoconversion).0646872768084889296100%
# Performing single-pass .bed write (1177 variants, 25 people).
# --file: results/ld/smv7_ex_autosomes_senegal_SM_V7_5-temporary.bed +444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394%
# results/ld/smv7_ex_autosomes_senegal_SM_V7_5-temporary.bim +
# results/ld/smv7_ex_autosomes_senegal_SM_V7_5-temporary.fam written.
# 1177 variants loaded from .bim file.
# 25 people (0 males, 0 females, 25 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to results/ld/smv7_ex_autosomes_senegal_SM_V7_5.nosex
# .
# Using up to 6 threads (change this with --threads).
# Before main variant filters, 25 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.851215.
# 1177 variants and 25 people pass filters and QC.
# Note: No phenotypes present.
# --r2 to results/ld/smv7_ex_autosomes_senegal_SM_V7_5.ld ... 0% [processingwriting]        done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Note: --recode12 flag deprecated.  Use "--recode 12 ...".
# Logging to results/ld/smv7_ex_autosomes_senegal_SM_V7_6.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --out results/ld/smv7_ex_autosomes_senegal_SM_V7_6
#   --recode 12
#   --threads 6
#   --vcf results/ld/smv7_ex_autosomes_senegal_SM_V7_6.vcf
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# --vcf: results/ld/smv7_ex_autosomes_senegal_SM_V7_6-temporary.bed +
# results/ld/smv7_ex_autosomes_senegal_SM_V7_6-temporary.bim +
# results/ld/smv7_ex_autosomes_senegal_SM_V7_6-temporary.fam written.
# 1048 variants loaded from .bim file.
# 25 people (0 males, 0 females, 25 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to results/ld/smv7_ex_autosomes_senegal_SM_V7_6.nosex
# .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 25 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.851069.
# 1048 variants and 25 people pass filters and QC.
# Note: No phenotypes present.
# --recode ped to results/ld/smv7_ex_autosomes_senegal_SM_V7_6.ped +
# results/ld/smv7_ex_autosomes_senegal_SM_V7_6.map ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to results/ld/smv7_ex_autosomes_senegal_SM_V7_6.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --file results/ld/smv7_ex_autosomes_senegal_SM_V7_6
#   --ld-window 1000000
#   --ld-window-kb 1000
#   --ld-window-r2 0.0
#   --out results/ld/smv7_ex_autosomes_senegal_SM_V7_6
#   --r2
#   --threads 6
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# .ped scan complete (for binary autoconversion).0646872768084889296100%
# Performing single-pass .bed write (1048 variants, 25 people).
# --file: results/ld/smv7_ex_autosomes_senegal_SM_V7_6-temporary.bed +444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394%
# results/ld/smv7_ex_autosomes_senegal_SM_V7_6-temporary.bim +
# results/ld/smv7_ex_autosomes_senegal_SM_V7_6-temporary.fam written.
# 1048 variants loaded from .bim file.
# 25 people (0 males, 0 females, 25 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to results/ld/smv7_ex_autosomes_senegal_SM_V7_6.nosex
# .
# Using up to 6 threads (change this with --threads).
# Before main variant filters, 25 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.851069.
# 1048 variants and 25 people pass filters and QC.
# Note: No phenotypes present.
# --r2 to results/ld/smv7_ex_autosomes_senegal_SM_V7_6.ld ... 0% [processingwriting]        done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Note: --recode12 flag deprecated.  Use "--recode 12 ...".
# Logging to results/ld/smv7_ex_autosomes_senegal_SM_V7_7.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --out results/ld/smv7_ex_autosomes_senegal_SM_V7_7
#   --recode 12
#   --threads 6
#   --vcf results/ld/smv7_ex_autosomes_senegal_SM_V7_7.vcf
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# --vcf: results/ld/smv7_ex_autosomes_senegal_SM_V7_7-temporary.bed +
# results/ld/smv7_ex_autosomes_senegal_SM_V7_7-temporary.bim +
# results/ld/smv7_ex_autosomes_senegal_SM_V7_7-temporary.fam written.
# 605 variants loaded from .bim file.
# 25 people (0 males, 0 females, 25 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to results/ld/smv7_ex_autosomes_senegal_SM_V7_7.nosex
# .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 25 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.850975.
# 605 variants and 25 people pass filters and QC.
# Note: No phenotypes present.
# --recode ped to results/ld/smv7_ex_autosomes_senegal_SM_V7_7.ped +
# results/ld/smv7_ex_autosomes_senegal_SM_V7_7.map ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to results/ld/smv7_ex_autosomes_senegal_SM_V7_7.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --file results/ld/smv7_ex_autosomes_senegal_SM_V7_7
#   --ld-window 1000000
#   --ld-window-kb 1000
#   --ld-window-r2 0.0
#   --out results/ld/smv7_ex_autosomes_senegal_SM_V7_7
#   --r2
#   --threads 6
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# .ped scan complete (for binary autoconversion).0646872768084889296100%
# Performing single-pass .bed write (605 variants, 25 people).
# --file: results/ld/smv7_ex_autosomes_senegal_SM_V7_7-temporary.bed +444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394%
# results/ld/smv7_ex_autosomes_senegal_SM_V7_7-temporary.bim +
# results/ld/smv7_ex_autosomes_senegal_SM_V7_7-temporary.fam written.
# 605 variants loaded from .bim file.
# 25 people (0 males, 0 females, 25 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to results/ld/smv7_ex_autosomes_senegal_SM_V7_7.nosex
# .
# Using up to 6 threads (change this with --threads).
# Before main variant filters, 25 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.850975.
# 605 variants and 25 people pass filters and QC.
# Note: No phenotypes present.
# --r2 to results/ld/smv7_ex_autosomes_senegal_SM_V7_7.ld ... 0% [processingwriting]        done.
# niger
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Note: --recode12 flag deprecated.  Use "--recode 12 ...".
# Logging to results/ld/smv7_ex_autosomes_niger_SM_V7_1.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --out results/ld/smv7_ex_autosomes_niger_SM_V7_1
#   --recode 12
#   --threads 6
#   --vcf results/ld/smv7_ex_autosomes_niger_SM_V7_1.vcf
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# --vcf: results/ld/smv7_ex_autosomes_niger_SM_V7_1-temporary.bed +
# results/ld/smv7_ex_autosomes_niger_SM_V7_1-temporary.bim +
# results/ld/smv7_ex_autosomes_niger_SM_V7_1-temporary.fam written.
# 6120 variants loaded from .bim file.
# 10 people (0 males, 0 females, 10 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to results/ld/smv7_ex_autosomes_niger_SM_V7_1.nosex .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 10 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.864118.
# 6120 variants and 10 people pass filters and QC.
# Note: No phenotypes present.
# --recode ped to results/ld/smv7_ex_autosomes_niger_SM_V7_1.ped +
# results/ld/smv7_ex_autosomes_niger_SM_V7_1.map ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to results/ld/smv7_ex_autosomes_niger_SM_V7_1.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --file results/ld/smv7_ex_autosomes_niger_SM_V7_1
#   --ld-window 1000000
#   --ld-window-kb 1000
#   --ld-window-r2 0.0
#   --out results/ld/smv7_ex_autosomes_niger_SM_V7_1
#   --r2
#   --threads 6
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# .ped scan complete (for binary autoconversion).
# Performing single-pass .bed write (6120 variants, 10 people).
# --file: results/ld/smv7_ex_autosomes_niger_SM_V7_1-temporary.bed +43444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394%
# results/ld/smv7_ex_autosomes_niger_SM_V7_1-temporary.bim +
# results/ld/smv7_ex_autosomes_niger_SM_V7_1-temporary.fam written.
# 6120 variants loaded from .bim file.
# 10 people (0 males, 0 females, 10 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to results/ld/smv7_ex_autosomes_niger_SM_V7_1.nosex .
# Using up to 6 threads (change this with --threads).
# Before main variant filters, 10 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.864118.
# 6120 variants and 10 people pass filters and QC.
# Note: No phenotypes present.
# --r2 to results/ld/smv7_ex_autosomes_niger_SM_V7_1.ld ... 0% [processingwriting]        done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Note: --recode12 flag deprecated.  Use "--recode 12 ...".
# Logging to results/ld/smv7_ex_autosomes_niger_SM_V7_2.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --out results/ld/smv7_ex_autosomes_niger_SM_V7_2
#   --recode 12
#   --threads 6
#   --vcf results/ld/smv7_ex_autosomes_niger_SM_V7_2.vcf
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# --vcf: results/ld/smv7_ex_autosomes_niger_SM_V7_2-temporary.bed +
# results/ld/smv7_ex_autosomes_niger_SM_V7_2-temporary.bim +
# results/ld/smv7_ex_autosomes_niger_SM_V7_2-temporary.fam written.
# 4661 variants loaded from .bim file.
# 10 people (0 males, 0 females, 10 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to results/ld/smv7_ex_autosomes_niger_SM_V7_2.nosex .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 10 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.832868.
# 4661 variants and 10 people pass filters and QC.
# Note: No phenotypes present.
# --recode ped to results/ld/smv7_ex_autosomes_niger_SM_V7_2.ped +
# results/ld/smv7_ex_autosomes_niger_SM_V7_2.map ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to results/ld/smv7_ex_autosomes_niger_SM_V7_2.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --file results/ld/smv7_ex_autosomes_niger_SM_V7_2
#   --ld-window 1000000
#   --ld-window-kb 1000
#   --ld-window-r2 0.0
#   --out results/ld/smv7_ex_autosomes_niger_SM_V7_2
#   --r2
#   --threads 6
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# .ped scan complete (for binary autoconversion).
# Performing single-pass .bed write (4661 variants, 10 people).
# --file: results/ld/smv7_ex_autosomes_niger_SM_V7_2-temporary.bed +43444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394%
# results/ld/smv7_ex_autosomes_niger_SM_V7_2-temporary.bim +
# results/ld/smv7_ex_autosomes_niger_SM_V7_2-temporary.fam written.
# 4661 variants loaded from .bim file.
# 10 people (0 males, 0 females, 10 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to results/ld/smv7_ex_autosomes_niger_SM_V7_2.nosex .
# Using up to 6 threads (change this with --threads).
# Before main variant filters, 10 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.832868.
# 4661 variants and 10 people pass filters and QC.
# Note: No phenotypes present.
# --r2 to results/ld/smv7_ex_autosomes_niger_SM_V7_2.ld ... 0% [processingwriting]        done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Note: --recode12 flag deprecated.  Use "--recode 12 ...".
# Logging to results/ld/smv7_ex_autosomes_niger_SM_V7_3.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --out results/ld/smv7_ex_autosomes_niger_SM_V7_3
#   --recode 12
#   --threads 6
#   --vcf results/ld/smv7_ex_autosomes_niger_SM_V7_3.vcf
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# --vcf: results/ld/smv7_ex_autosomes_niger_SM_V7_3-temporary.bed +
# results/ld/smv7_ex_autosomes_niger_SM_V7_3-temporary.bim +
# results/ld/smv7_ex_autosomes_niger_SM_V7_3-temporary.fam written.
# 4573 variants loaded from .bim file.
# 10 people (0 males, 0 females, 10 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to results/ld/smv7_ex_autosomes_niger_SM_V7_3.nosex .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 10 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.848786.
# 4573 variants and 10 people pass filters and QC.
# Note: No phenotypes present.
# --recode ped to results/ld/smv7_ex_autosomes_niger_SM_V7_3.ped +
# results/ld/smv7_ex_autosomes_niger_SM_V7_3.map ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to results/ld/smv7_ex_autosomes_niger_SM_V7_3.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --file results/ld/smv7_ex_autosomes_niger_SM_V7_3
#   --ld-window 1000000
#   --ld-window-kb 1000
#   --ld-window-r2 0.0
#   --out results/ld/smv7_ex_autosomes_niger_SM_V7_3
#   --r2
#   --threads 6
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# .ped scan complete (for binary autoconversion).
# Performing single-pass .bed write (4573 variants, 10 people).
# --file: results/ld/smv7_ex_autosomes_niger_SM_V7_3-temporary.bed +43444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394%
# results/ld/smv7_ex_autosomes_niger_SM_V7_3-temporary.bim +
# results/ld/smv7_ex_autosomes_niger_SM_V7_3-temporary.fam written.
# 4573 variants loaded from .bim file.
# 10 people (0 males, 0 females, 10 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to results/ld/smv7_ex_autosomes_niger_SM_V7_3.nosex .
# Using up to 6 threads (change this with --threads).
# Before main variant filters, 10 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.848786.
# 4573 variants and 10 people pass filters and QC.
# Note: No phenotypes present.
# --r2 to results/ld/smv7_ex_autosomes_niger_SM_V7_3.ld ... 0% [processingwriting]        done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Note: --recode12 flag deprecated.  Use "--recode 12 ...".
# Logging to results/ld/smv7_ex_autosomes_niger_SM_V7_4.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --out results/ld/smv7_ex_autosomes_niger_SM_V7_4
#   --recode 12
#   --threads 6
#   --vcf results/ld/smv7_ex_autosomes_niger_SM_V7_4.vcf
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# --vcf: results/ld/smv7_ex_autosomes_niger_SM_V7_4-temporary.bed +
# results/ld/smv7_ex_autosomes_niger_SM_V7_4-temporary.bim +
# results/ld/smv7_ex_autosomes_niger_SM_V7_4-temporary.fam written.
# 3253 variants loaded from .bim file.
# 10 people (0 males, 0 females, 10 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to results/ld/smv7_ex_autosomes_niger_SM_V7_4.nosex .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 10 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.845773.
# 3253 variants and 10 people pass filters and QC.
# Note: No phenotypes present.
# --recode ped to results/ld/smv7_ex_autosomes_niger_SM_V7_4.ped +
# results/ld/smv7_ex_autosomes_niger_SM_V7_4.map ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to results/ld/smv7_ex_autosomes_niger_SM_V7_4.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --file results/ld/smv7_ex_autosomes_niger_SM_V7_4
#   --ld-window 1000000
#   --ld-window-kb 1000
#   --ld-window-r2 0.0
#   --out results/ld/smv7_ex_autosomes_niger_SM_V7_4
#   --r2
#   --threads 6
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# .ped scan complete (for binary autoconversion).
# Performing single-pass .bed write (3253 variants, 10 people).
# --file: results/ld/smv7_ex_autosomes_niger_SM_V7_4-temporary.bed +43444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394%
# results/ld/smv7_ex_autosomes_niger_SM_V7_4-temporary.bim +
# results/ld/smv7_ex_autosomes_niger_SM_V7_4-temporary.fam written.
# 3253 variants loaded from .bim file.
# 10 people (0 males, 0 females, 10 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to results/ld/smv7_ex_autosomes_niger_SM_V7_4.nosex .
# Using up to 6 threads (change this with --threads).
# Before main variant filters, 10 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.845773.
# 3253 variants and 10 people pass filters and QC.
# Note: No phenotypes present.
# --r2 to results/ld/smv7_ex_autosomes_niger_SM_V7_4.ld ... 0% [processingwriting]        done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Note: --recode12 flag deprecated.  Use "--recode 12 ...".
# Logging to results/ld/smv7_ex_autosomes_niger_SM_V7_5.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --out results/ld/smv7_ex_autosomes_niger_SM_V7_5
#   --recode 12
#   --threads 6
#   --vcf results/ld/smv7_ex_autosomes_niger_SM_V7_5.vcf
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# --vcf: results/ld/smv7_ex_autosomes_niger_SM_V7_5-temporary.bed +
# results/ld/smv7_ex_autosomes_niger_SM_V7_5-temporary.bim +
# results/ld/smv7_ex_autosomes_niger_SM_V7_5-temporary.fam written.
# 2138 variants loaded from .bim file.
# 10 people (0 males, 0 females, 10 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to results/ld/smv7_ex_autosomes_niger_SM_V7_5.nosex .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 10 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.826099.
# 2138 variants and 10 people pass filters and QC.
# Note: No phenotypes present.
# --recode ped to results/ld/smv7_ex_autosomes_niger_SM_V7_5.ped +
# results/ld/smv7_ex_autosomes_niger_SM_V7_5.map ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to results/ld/smv7_ex_autosomes_niger_SM_V7_5.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --file results/ld/smv7_ex_autosomes_niger_SM_V7_5
#   --ld-window 1000000
#   --ld-window-kb 1000
#   --ld-window-r2 0.0
#   --out results/ld/smv7_ex_autosomes_niger_SM_V7_5
#   --r2
#   --threads 6
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# .ped scan complete (for binary autoconversion).
# Performing single-pass .bed write (2138 variants, 10 people).
# --file: results/ld/smv7_ex_autosomes_niger_SM_V7_5-temporary.bed +43444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394%
# results/ld/smv7_ex_autosomes_niger_SM_V7_5-temporary.bim +
# results/ld/smv7_ex_autosomes_niger_SM_V7_5-temporary.fam written.
# 2138 variants loaded from .bim file.
# 10 people (0 males, 0 females, 10 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to results/ld/smv7_ex_autosomes_niger_SM_V7_5.nosex .
# Using up to 6 threads (change this with --threads).
# Before main variant filters, 10 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.826099.
# 2138 variants and 10 people pass filters and QC.
# Note: No phenotypes present.
# --r2 to results/ld/smv7_ex_autosomes_niger_SM_V7_5.ld ... 0% [processingwriting]        done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Note: --recode12 flag deprecated.  Use "--recode 12 ...".
# Logging to results/ld/smv7_ex_autosomes_niger_SM_V7_6.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --out results/ld/smv7_ex_autosomes_niger_SM_V7_6
#   --recode 12
#   --threads 6
#   --vcf results/ld/smv7_ex_autosomes_niger_SM_V7_6.vcf
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# --vcf: results/ld/smv7_ex_autosomes_niger_SM_V7_6-temporary.bed +
# results/ld/smv7_ex_autosomes_niger_SM_V7_6-temporary.bim +
# results/ld/smv7_ex_autosomes_niger_SM_V7_6-temporary.fam written.
# 2044 variants loaded from .bim file.
# 10 people (0 males, 0 females, 10 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to results/ld/smv7_ex_autosomes_niger_SM_V7_6.nosex .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 10 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.812231.
# 2044 variants and 10 people pass filters and QC.
# Note: No phenotypes present.
# --recode ped to results/ld/smv7_ex_autosomes_niger_SM_V7_6.ped +
# results/ld/smv7_ex_autosomes_niger_SM_V7_6.map ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to results/ld/smv7_ex_autosomes_niger_SM_V7_6.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --file results/ld/smv7_ex_autosomes_niger_SM_V7_6
#   --ld-window 1000000
#   --ld-window-kb 1000
#   --ld-window-r2 0.0
#   --out results/ld/smv7_ex_autosomes_niger_SM_V7_6
#   --r2
#   --threads 6
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# .ped scan complete (for binary autoconversion).
# Performing single-pass .bed write (2044 variants, 10 people).
# --file: results/ld/smv7_ex_autosomes_niger_SM_V7_6-temporary.bed +43444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394%
# results/ld/smv7_ex_autosomes_niger_SM_V7_6-temporary.bim +
# results/ld/smv7_ex_autosomes_niger_SM_V7_6-temporary.fam written.
# 2044 variants loaded from .bim file.
# 10 people (0 males, 0 females, 10 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to results/ld/smv7_ex_autosomes_niger_SM_V7_6.nosex .
# Using up to 6 threads (change this with --threads).
# Before main variant filters, 10 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.812231.
# 2044 variants and 10 people pass filters and QC.
# Note: No phenotypes present.
# --r2 to results/ld/smv7_ex_autosomes_niger_SM_V7_6.ld ... 0% [processingwriting]        done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Note: --recode12 flag deprecated.  Use "--recode 12 ...".
# Logging to results/ld/smv7_ex_autosomes_niger_SM_V7_7.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --out results/ld/smv7_ex_autosomes_niger_SM_V7_7
#   --recode 12
#   --threads 6
#   --vcf results/ld/smv7_ex_autosomes_niger_SM_V7_7.vcf
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# --vcf: results/ld/smv7_ex_autosomes_niger_SM_V7_7-temporary.bed +
# results/ld/smv7_ex_autosomes_niger_SM_V7_7-temporary.bim +
# results/ld/smv7_ex_autosomes_niger_SM_V7_7-temporary.fam written.
# 1259 variants loaded from .bim file.
# 10 people (0 males, 0 females, 10 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to results/ld/smv7_ex_autosomes_niger_SM_V7_7.nosex .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 10 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.82645.
# 1259 variants and 10 people pass filters and QC.
# Note: No phenotypes present.
# --recode ped to results/ld/smv7_ex_autosomes_niger_SM_V7_7.ped +
# results/ld/smv7_ex_autosomes_niger_SM_V7_7.map ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to results/ld/smv7_ex_autosomes_niger_SM_V7_7.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --file results/ld/smv7_ex_autosomes_niger_SM_V7_7
#   --ld-window 1000000
#   --ld-window-kb 1000
#   --ld-window-r2 0.0
#   --out results/ld/smv7_ex_autosomes_niger_SM_V7_7
#   --r2
#   --threads 6
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# .ped scan complete (for binary autoconversion).
# Performing single-pass .bed write (1259 variants, 10 people).
# --file: results/ld/smv7_ex_autosomes_niger_SM_V7_7-temporary.bed +43444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394%
# results/ld/smv7_ex_autosomes_niger_SM_V7_7-temporary.bim +
# results/ld/smv7_ex_autosomes_niger_SM_V7_7-temporary.fam written.
# 1259 variants loaded from .bim file.
# 10 people (0 males, 0 females, 10 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to results/ld/smv7_ex_autosomes_niger_SM_V7_7.nosex .
# Using up to 6 threads (change this with --threads).
# Before main variant filters, 10 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.82645.
# 1259 variants and 10 people pass filters and QC.
# Note: No phenotypes present.
# --r2 to results/ld/smv7_ex_autosomes_niger_SM_V7_7.ld ... 0% [processingwriting]        done.
# brazil
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Note: --recode12 flag deprecated.  Use "--recode 12 ...".
# Logging to results/ld/smv7_ex_autosomes_brazil_SM_V7_1.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --out results/ld/smv7_ex_autosomes_brazil_SM_V7_1
#   --recode 12
#   --threads 6
#   --vcf results/ld/smv7_ex_autosomes_brazil_SM_V7_1.vcf
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# --vcf: results/ld/smv7_ex_autosomes_brazil_SM_V7_1-temporary.bed +
# results/ld/smv7_ex_autosomes_brazil_SM_V7_1-temporary.bim +
# results/ld/smv7_ex_autosomes_brazil_SM_V7_1-temporary.fam written.
# 5337 variants loaded from .bim file.
# 45 people (0 males, 0 females, 45 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to results/ld/smv7_ex_autosomes_brazil_SM_V7_1.nosex
# .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 45 founders and 0 nonfounders present.
# ...
# Total genotyping rate is 0.806714.
# 7355 variants and 55 people pass filters and QC.
# Note: No phenotypes present.
# --recode ped to results/ld/smv7_ex_autosomes_tanzania_SM_V7_3.ped +
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_3.map ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to results/ld/smv7_ex_autosomes_tanzania_SM_V7_3.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --file results/ld/smv7_ex_autosomes_tanzania_SM_V7_3
#   --ld-window 1000000
#   --ld-window-kb 1000
#   --ld-window-r2 0.0
#   --out results/ld/smv7_ex_autosomes_tanzania_SM_V7_3
#   --r2
#   --threads 6
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# .ped scan complete (for binary autoconversion).2343638404143454749505254565860616365676970727476788081838587899092949698100%
# Performing single-pass .bed write (7355 variants, 55 people).
# --file: results/ld/smv7_ex_autosomes_tanzania_SM_V7_3-temporary.bed +44546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394%
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_3-temporary.bim +
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_3-temporary.fam written.
# 7355 variants loaded from .bim file.
# 55 people (0 males, 0 females, 55 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_3.nosex .
# Using up to 6 threads (change this with --threads).
# Before main variant filters, 55 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.806714.
# 7355 variants and 55 people pass filters and QC.
# Note: No phenotypes present.
# --r2 to results/ld/smv7_ex_autosomes_tanzania_SM_V7_3.ld ... 0% [processingwriting]        done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Note: --recode12 flag deprecated.  Use "--recode 12 ...".
# Logging to results/ld/smv7_ex_autosomes_tanzania_SM_V7_4.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --out results/ld/smv7_ex_autosomes_tanzania_SM_V7_4
#   --recode 12
#   --threads 6
#   --vcf results/ld/smv7_ex_autosomes_tanzania_SM_V7_4.vcf
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# --vcf: results/ld/smv7_ex_autosomes_tanzania_SM_V7_4-temporary.bed +
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_4-temporary.bim +
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_4-temporary.fam written.
# 6818 variants loaded from .bim file.
# 55 people (0 males, 0 females, 55 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_4.nosex .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 55 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.806424.
# 6818 variants and 55 people pass filters and QC.
# Note: No phenotypes present.
# --recode ped to results/ld/smv7_ex_autosomes_tanzania_SM_V7_4.ped +
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_4.map ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to results/ld/smv7_ex_autosomes_tanzania_SM_V7_4.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --file results/ld/smv7_ex_autosomes_tanzania_SM_V7_4
#   --ld-window 1000000
#   --ld-window-kb 1000
#   --ld-window-r2 0.0
#   --out results/ld/smv7_ex_autosomes_tanzania_SM_V7_4
#   --r2
#   --threads 6
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# .ped scan complete (for binary autoconversion).2343638404143454749505254565860616365676970727476788081838587899092949698100%
# Performing single-pass .bed write (6818 variants, 55 people).
# --file: results/ld/smv7_ex_autosomes_tanzania_SM_V7_4-temporary.bed +44546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394%
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_4-temporary.bim +
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_4-temporary.fam written.
# 6818 variants loaded from .bim file.
# 55 people (0 males, 0 females, 55 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_4.nosex .
# Using up to 6 threads (change this with --threads).
# Before main variant filters, 55 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.806424.
# 6818 variants and 55 people pass filters and QC.
# Note: No phenotypes present.
# --r2 to results/ld/smv7_ex_autosomes_tanzania_SM_V7_4.ld ... 0% [processingwriting]        done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Note: --recode12 flag deprecated.  Use "--recode 12 ...".
# Logging to results/ld/smv7_ex_autosomes_tanzania_SM_V7_5.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --out results/ld/smv7_ex_autosomes_tanzania_SM_V7_5
#   --recode 12
#   --threads 6
#   --vcf results/ld/smv7_ex_autosomes_tanzania_SM_V7_5.vcf
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# --vcf: results/ld/smv7_ex_autosomes_tanzania_SM_V7_5-temporary.bed +
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_5-temporary.bim +
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_5-temporary.fam written.
# 3148 variants loaded from .bim file.
# 55 people (0 males, 0 females, 55 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_5.nosex .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 55 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.78585.
# 3148 variants and 55 people pass filters and QC.
# Note: No phenotypes present.
# --recode ped to results/ld/smv7_ex_autosomes_tanzania_SM_V7_5.ped +
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_5.map ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to results/ld/smv7_ex_autosomes_tanzania_SM_V7_5.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --file results/ld/smv7_ex_autosomes_tanzania_SM_V7_5
#   --ld-window 1000000
#   --ld-window-kb 1000
#   --ld-window-r2 0.0
#   --out results/ld/smv7_ex_autosomes_tanzania_SM_V7_5
#   --r2
#   --threads 6
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# .ped scan complete (for binary autoconversion).2343638404143454749505254565860616365676970727476788081838587899092949698100%
# Performing single-pass .bed write (3148 variants, 55 people).
# --file: results/ld/smv7_ex_autosomes_tanzania_SM_V7_5-temporary.bed +44546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394%
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_5-temporary.bim +
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_5-temporary.fam written.
# 3148 variants loaded from .bim file.
# 55 people (0 males, 0 females, 55 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_5.nosex .
# Using up to 6 threads (change this with --threads).
# Before main variant filters, 55 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.78585.
# 3148 variants and 55 people pass filters and QC.
# Note: No phenotypes present.
# --r2 to results/ld/smv7_ex_autosomes_tanzania_SM_V7_5.ld ... 0% [processingwriting]        done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Note: --recode12 flag deprecated.  Use "--recode 12 ...".
# Logging to results/ld/smv7_ex_autosomes_tanzania_SM_V7_6.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --out results/ld/smv7_ex_autosomes_tanzania_SM_V7_6
#   --recode 12
#   --threads 6
#   --vcf results/ld/smv7_ex_autosomes_tanzania_SM_V7_6.vcf
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# --vcf: results/ld/smv7_ex_autosomes_tanzania_SM_V7_6-temporary.bed +
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_6-temporary.bim +
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_6-temporary.fam written.
# 3324 variants loaded from .bim file.
# 55 people (0 males, 0 females, 55 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_6.nosex .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 55 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.784805.
# 3324 variants and 55 people pass filters and QC.
# Note: No phenotypes present.
# --recode ped to results/ld/smv7_ex_autosomes_tanzania_SM_V7_6.ped +
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_6.map ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to results/ld/smv7_ex_autosomes_tanzania_SM_V7_6.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --file results/ld/smv7_ex_autosomes_tanzania_SM_V7_6
#   --ld-window 1000000
#   --ld-window-kb 1000
#   --ld-window-r2 0.0
#   --out results/ld/smv7_ex_autosomes_tanzania_SM_V7_6
#   --r2
#   --threads 6
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# .ped scan complete (for binary autoconversion).2343638404143454749505254565860616365676970727476788081838587899092949698100%
# Performing single-pass .bed write (3324 variants, 55 people).
# --file: results/ld/smv7_ex_autosomes_tanzania_SM_V7_6-temporary.bed +44546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394%
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_6-temporary.bim +
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_6-temporary.fam written.
# 3324 variants loaded from .bim file.
# 55 people (0 males, 0 females, 55 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_6.nosex .
# Using up to 6 threads (change this with --threads).
# Before main variant filters, 55 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.784805.
# 3324 variants and 55 people pass filters and QC.
# Note: No phenotypes present.
# --r2 to results/ld/smv7_ex_autosomes_tanzania_SM_V7_6.ld ... 0% [processingwriting]        done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Note: --recode12 flag deprecated.  Use "--recode 12 ...".
# Logging to results/ld/smv7_ex_autosomes_tanzania_SM_V7_7.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --out results/ld/smv7_ex_autosomes_tanzania_SM_V7_7
#   --recode 12
#   --threads 6
#   --vcf results/ld/smv7_ex_autosomes_tanzania_SM_V7_7.vcf
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# --vcf: results/ld/smv7_ex_autosomes_tanzania_SM_V7_7-temporary.bed +
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_7-temporary.bim +
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_7-temporary.fam written.
# 2574 variants loaded from .bim file.
# 55 people (0 males, 0 females, 55 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_7.nosex .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 55 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.787985.
# 2574 variants and 55 people pass filters and QC.
# Note: No phenotypes present.
# --recode ped to results/ld/smv7_ex_autosomes_tanzania_SM_V7_7.ped +
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_7.map ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to results/ld/smv7_ex_autosomes_tanzania_SM_V7_7.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --file results/ld/smv7_ex_autosomes_tanzania_SM_V7_7
#   --ld-window 1000000
#   --ld-window-kb 1000
#   --ld-window-r2 0.0
#   --out results/ld/smv7_ex_autosomes_tanzania_SM_V7_7
#   --r2
#   --threads 6
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# .ped scan complete (for binary autoconversion).2343638404143454749505254565860616365676970727476788081838587899092949698100%
# Performing single-pass .bed write (2574 variants, 55 people).
# --file: results/ld/smv7_ex_autosomes_tanzania_SM_V7_7-temporary.bed +44546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394%
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_7-temporary.bim +
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_7-temporary.fam written.
# 2574 variants loaded from .bim file.
# 55 people (0 males, 0 females, 55 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_7.nosex .
# Using up to 6 threads (change this with --threads).
# Before main variant filters, 55 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.787985.
# 2574 variants and 55 people pass filters and QC.
# Note: No phenotypes present.
# --r2 to results/ld/smv7_ex_autosomes_tanzania_SM_V7_7.ld ... 0% [processingwriting]        done.

# %% [markdown]
# Make new files that contain all R2 info from Plink, but also add distance between SNP-A and SNP-B.

# %%
#create tables
for pop in ["senegal", "niger", "brazil", "tanzania"]:
    print(pop)
    
    in_list = "results/ld/{}.list".format(pop)
    
    #open the outfile that will contain ALL of the data (and add a header)
    with open("results/ld/smv7_ex_autosomes_{}_dist.tbl".format(pop), 'w') as merged_all_out_file:
        #print header line
        header_line="chr_a\tbp_a\tsnp_a\tchr_b\tbp_b\tsnp_b\tr2\ta_b_dist\n"
        merged_all_out_file.write(header_line)
        
        #open each chrom specific ld file (and skip the header)
        for chrom in list(range(1, 8)):
            chrom="SM_V7_{}".format(chrom)
            plink_file="results/ld/smv7_ex_autosomes_{}_{}.ld".format(pop, chrom)

            with open(plink_file, 'r') as in_file:
                next(in_file)

                #for each r2 calc
                for entry in in_file:
                    entry=','.join(entry.split())
                    chr_a, bp_a, snp_a, chr_b, bp_b, snp_b, r2 = entry.split(",")

                    #calculate the distance between the snps
                    a_b_dist = int(bp_b) - int(bp_a)
                    outline=[chr_a, bp_a, snp_a, chr_b, bp_b, snp_b, r2, str(a_b_dist), "\n"]
                    outline="\t".join(outline)

                    #and print to the ALL output file
                    merged_all_out_file.write(outline)
# Out:
# senegal
# niger
# brazil
# tanzania

# %%
#clean up all of the unused files
for pop in ["senegal", "niger", "brazil", "tanzania"]:
    for chrom in list(range(1, 8)):
        chrom="SM_V7_{}".format(chrom)
        for ext in ["ld", "map", "ped", "log", "nosex", "vcf"]:
            file_to_del="results/ld/smv7_ex_autosomes_{}_{}.{}".format(pop, chrom, ext)
            if os.path.exists(file_to_del):
                os.remove(file_to_del)

# %% [markdown]
# ## Calc. mean R2 values per bin/distance

# %%
#read in plink R2 data and create a df to save
dists=defaultdict(lambda: list())
r2s=defaultdict(lambda: list())

for pop in ["niger", "senegal", "brazil", "tanzania"]:
    print(pop)

    with open("results/ld/smv7_ex_autosomes_{}_dist.tbl".format(pop), 'r') as in_file:
        #skip header line
        next(in_file)

        for entry in in_file:
            chr_a, bp_a, snp_a, chr_b, bp_b, snp_b, r2, a_b_dist = entry.rstrip().split("\t")
            r2s[pop].append(float(r2))
            dists[pop].append(int(a_b_dist))

#convert to np array
for pop in ["niger", "senegal", "brazil", "tanzania"]:
    dists[pop]=np.array(dists[pop])
    r2s[pop]=np.array(r2s[pop])

    
#create bins for stat binning
bins=np.geomspace(1, 1_000_000, num=1000)

#get mean values for each bin
n, bin_edges, binnumber=stats.binned_statistic(dists["niger"], r2s["niger"], statistic='mean', bins=bins)
b, bin_edges, binnumber=stats.binned_statistic(dists["brazil"], r2s["brazil"], statistic='mean', bins=bins)
s, bin_edges, binnumber=stats.binned_statistic(dists["senegal"], r2s["senegal"], statistic='mean', bins=bins)
t, bin_edges, binnumber=stats.binned_statistic(dists["tanzania"], r2s["tanzania"], statistic='mean', bins=bins)

#save data to a csv for ease of access later
df=pd.DataFrame(data=[bin_edges[:-1], n, b, s, t]).T.dropna()
df.columns=["distance_bin", "niger_r2", "brazil_r2", "senegal_r2", "tanzania_r2"]
df.to_csv("results/ld/ld_dist_binned_smoothed_pybins.csv", sep=",")
# df
# Out:
# niger
# senegal
# brazil
# tanzania

# %% [markdown]
# # Plot

# %%
plt.scatter(df["distance_bin"], df["niger_r2"],    s=3, c="orange",    label="Niger")
plt.scatter(df["distance_bin"], df["senegal_r2"],  s=3, c="blue", label="Senegal")
plt.scatter(df["distance_bin"], df["tanzania_r2"], s=3, c="red",  label="Tanzania")
plt.scatter(df["distance_bin"], df["brazil_r2"],   s=3, c="green",   label="Brazil")
plt.xlabel("Distance (bp)")
plt.ylabel("R2")
#plt.xscale('log')
plt.ylim(0,1)
#plt.xlim(0,200_000)
#plt.legend(title="Populations (MAF=0.05)", markerscale=3)

#plt.savefig("results/ld/ld_decay_maf05.svg")
#plt.savefig("results/ld/ld_decay_maf05.png")

plt.show()
plt.close()

# %%
x=bin_edges[1:]

for y, label, color in [(t, "Tanzania", "red"), 
                 (b, "Brazil", "green"),
                 (s, "Senegal", "blue"),
                 (n, "Niger", "orange")]:

    #plot
    plt.scatter(x, y, s=10, alpha=0.1, c=color)
    
    #smooth
    l=lowess(y, x, frac=0.15)
    xl=l[:,0]
    yl=l[:,1]
    plt.plot(xl, yl, label=label, c=color)
    
    #get ld50
    decay = interp1d(yl, xl, bounds_error=False)
    
    #what point is Ld50 In 250kb
    #OVER A MB ld=yl[0] - ((yl[0]-yl[x==x[-1]])/2)
    #ld=yl[0] - ((yl[0]-yl[-1])/2)
    ld50=int(decay(0.5))
    
    #add line to chart
    plt.vlines(ld50, 0, 0.5, colors=color, linestyle='dashed', linewidth=2, alpha=1)
    #plt.hlines(ld, ld50, ld, colors=color, linestyle='dashed', linewidth=2, alpha=0.5)

    print("{}: {}".format(label, ld50))

#plt.hlines(0.5, 1, 1e6, colors="black", linestyle='dashed', linewidth=2, alpha=0.5)
plt.ylim(0,1)
plt.xlim(10,10e5)
plt.legend(title="Populations")
plt.xlabel("Distance (base pairs)", fontsize=12)
plt.ylabel("Linkage disequilibrium ($\it{r}$$^2$)", fontsize=12)
plt.xscale('log')
plt.yticks(np.arange(0,1.1,0.25)) 
plt.savefig("results/ld/ld50_maf05.svg")
plt.savefig("results/ld/ld50_maf05.png")
#plt.grid()
plt.show()
# $10^1$
# Out:
# Tanzania: 28
# Brazil: 26196
# Senegal: 19318
# Niger: 15150

# %%
plt.boxplot([ dists["niger"][r2s["niger"]<0.2],
              dists["senegal"][r2s["senegal"]<0.2],
              dists["brazil"][r2s["brazil"]<0.2],
              dists["tanzania"][r2s["tanzania"]<0.2] ],
            showfliers=False, 
            notch=True,
            labels=["Niger", "Senegal", "Brazil", "Tanzania"])
plt.ylabel("Distance")
plt.show()

# %% [markdown]
# # Playing with long range LD

# %%
in_vcf="results/variant_filtration/smv7_ex_autosomes.vcf"

for pop in ["senegal", "niger", "brazil", "tanzania"]:
    print(pop)
    in_list = "results/ld/{}.list".format(pop)
    
    for chrom in list(range(1, 8)):
        chrom="SM_V7_{}".format(chrom)
        out_vcf = "results/ld/smv7_ex_autosomes_{}_{}.vcf".format(pop, chrom)
        
        #get ld chrom vcf
        vcf_cmd="vcftools --vcf {} --maf 0.05 --chr {} --keep {} --recode --recode-INFO-all --stdout >{}".format(in_vcf, chrom, in_list, out_vcf)
        # !{vcf_cmd}

        #convert vcf to plink
        plink_prefix="results/ld/smv7_ex_autosomes_{}_{}".format(pop, chrom)
        plink_cmd="plink --threads 6 --vcf {} --out {} --double-id --recode12 --allow-extra-chr".format(out_vcf, plink_prefix)
        # !{plink_cmd}  
        
        #calculate R2 between all snps on a chr
        plink_cmd="plink --threads 6 --r2 --file {} --out {} --double-id --allow-extra-chr --ld-window-r2 0.0 --ld-window 1000000 --ld-window-kb 1000".format(plink_prefix, plink_prefix)
        # !{plink_cmd}
# Out:
# senegal
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Note: --recode12 flag deprecated.  Use "--recode 12 ...".
# Logging to results/ld/smv7_ex_autosomes_senegal_SM_V7_1.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --out results/ld/smv7_ex_autosomes_senegal_SM_V7_1
#   --recode 12
#   --threads 6
#   --vcf results/ld/smv7_ex_autosomes_senegal_SM_V7_1.vcf
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# --vcf: results/ld/smv7_ex_autosomes_senegal_SM_V7_1-temporary.bed +
# results/ld/smv7_ex_autosomes_senegal_SM_V7_1-temporary.bim +
# results/ld/smv7_ex_autosomes_senegal_SM_V7_1-temporary.fam written.
# 2680 variants loaded from .bim file.
# 25 people (0 males, 0 females, 25 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to results/ld/smv7_ex_autosomes_senegal_SM_V7_1.nosex
# .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 25 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.884567.
# 2680 variants and 25 people pass filters and QC.
# Note: No phenotypes present.
# --recode ped to results/ld/smv7_ex_autosomes_senegal_SM_V7_1.ped +
# results/ld/smv7_ex_autosomes_senegal_SM_V7_1.map ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to results/ld/smv7_ex_autosomes_senegal_SM_V7_1.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --file results/ld/smv7_ex_autosomes_senegal_SM_V7_1
#   --ld-window 1000000
#   --ld-window-kb 1000
#   --ld-window-r2 0.0
#   --out results/ld/smv7_ex_autosomes_senegal_SM_V7_1
#   --r2
#   --threads 6
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# .ped scan complete (for binary autoconversion).0646872768084889296100%
# Performing single-pass .bed write (2680 variants, 25 people).
# --file: results/ld/smv7_ex_autosomes_senegal_SM_V7_1-temporary.bed +444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394%
# results/ld/smv7_ex_autosomes_senegal_SM_V7_1-temporary.bim +
# results/ld/smv7_ex_autosomes_senegal_SM_V7_1-temporary.fam written.
# 2680 variants loaded from .bim file.
# 25 people (0 males, 0 females, 25 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to results/ld/smv7_ex_autosomes_senegal_SM_V7_1.nosex
# .
# Using up to 6 threads (change this with --threads).
# Before main variant filters, 25 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.884567.
# 2680 variants and 25 people pass filters and QC.
# Note: No phenotypes present.
# --r2 to results/ld/smv7_ex_autosomes_senegal_SM_V7_1.ld ... 0% [processingwriting]        done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Note: --recode12 flag deprecated.  Use "--recode 12 ...".
# Logging to results/ld/smv7_ex_autosomes_senegal_SM_V7_2.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --out results/ld/smv7_ex_autosomes_senegal_SM_V7_2
#   --recode 12
#   --threads 6
#   --vcf results/ld/smv7_ex_autosomes_senegal_SM_V7_2.vcf
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# --vcf: results/ld/smv7_ex_autosomes_senegal_SM_V7_2-temporary.bed +
# results/ld/smv7_ex_autosomes_senegal_SM_V7_2-temporary.bim +
# results/ld/smv7_ex_autosomes_senegal_SM_V7_2-temporary.fam written.
# 4196 variants loaded from .bim file.
# 25 people (0 males, 0 females, 25 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to results/ld/smv7_ex_autosomes_senegal_SM_V7_2.nosex
# .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 25 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.868503.
# 4196 variants and 25 people pass filters and QC.
# Note: No phenotypes present.
# --recode ped to results/ld/smv7_ex_autosomes_senegal_SM_V7_2.ped +
# results/ld/smv7_ex_autosomes_senegal_SM_V7_2.map ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to results/ld/smv7_ex_autosomes_senegal_SM_V7_2.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --file results/ld/smv7_ex_autosomes_senegal_SM_V7_2
#   --ld-window 1000000
#   --ld-window-kb 1000
#   --ld-window-r2 0.0
#   --out results/ld/smv7_ex_autosomes_senegal_SM_V7_2
#   --r2
#   --threads 6
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# .ped scan complete (for binary autoconversion).0646872768084889296100%
# Performing single-pass .bed write (4196 variants, 25 people).
# --file: results/ld/smv7_ex_autosomes_senegal_SM_V7_2-temporary.bed +444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394%
# results/ld/smv7_ex_autosomes_senegal_SM_V7_2-temporary.bim +
# results/ld/smv7_ex_autosomes_senegal_SM_V7_2-temporary.fam written.
# 4196 variants loaded from .bim file.
# 25 people (0 males, 0 females, 25 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to results/ld/smv7_ex_autosomes_senegal_SM_V7_2.nosex
# .
# Using up to 6 threads (change this with --threads).
# Before main variant filters, 25 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.868503.
# 4196 variants and 25 people pass filters and QC.
# Note: No phenotypes present.
# --r2 to results/ld/smv7_ex_autosomes_senegal_SM_V7_2.ld ... 0% [processingwriting]        done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Note: --recode12 flag deprecated.  Use "--recode 12 ...".
# Logging to results/ld/smv7_ex_autosomes_senegal_SM_V7_3.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --out results/ld/smv7_ex_autosomes_senegal_SM_V7_3
#   --recode 12
#   --threads 6
#   --vcf results/ld/smv7_ex_autosomes_senegal_SM_V7_3.vcf
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# --vcf: results/ld/smv7_ex_autosomes_senegal_SM_V7_3-temporary.bed +
# results/ld/smv7_ex_autosomes_senegal_SM_V7_3-temporary.bim +
# results/ld/smv7_ex_autosomes_senegal_SM_V7_3-temporary.fam written.
# 3071 variants loaded from .bim file.
# 25 people (0 males, 0 females, 25 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to results/ld/smv7_ex_autosomes_senegal_SM_V7_3.nosex
# .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 25 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.869385.
# 3071 variants and 25 people pass filters and QC.
# Note: No phenotypes present.
# --recode ped to results/ld/smv7_ex_autosomes_senegal_SM_V7_3.ped +
# results/ld/smv7_ex_autosomes_senegal_SM_V7_3.map ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to results/ld/smv7_ex_autosomes_senegal_SM_V7_3.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --file results/ld/smv7_ex_autosomes_senegal_SM_V7_3
#   --ld-window 1000000
#   --ld-window-kb 1000
#   --ld-window-r2 0.0
#   --out results/ld/smv7_ex_autosomes_senegal_SM_V7_3
#   --r2
#   --threads 6
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# .ped scan complete (for binary autoconversion).0646872768084889296100%
# Performing single-pass .bed write (3071 variants, 25 people).
# --file: results/ld/smv7_ex_autosomes_senegal_SM_V7_3-temporary.bed +444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394%
# results/ld/smv7_ex_autosomes_senegal_SM_V7_3-temporary.bim +
# results/ld/smv7_ex_autosomes_senegal_SM_V7_3-temporary.fam written.
# 3071 variants loaded from .bim file.
# 25 people (0 males, 0 females, 25 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to results/ld/smv7_ex_autosomes_senegal_SM_V7_3.nosex
# .
# Using up to 6 threads (change this with --threads).
# Before main variant filters, 25 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.869385.
# 3071 variants and 25 people pass filters and QC.
# Note: No phenotypes present.
# --r2 to results/ld/smv7_ex_autosomes_senegal_SM_V7_3.ld ... 0% [processingwriting]        done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Note: --recode12 flag deprecated.  Use "--recode 12 ...".
# Logging to results/ld/smv7_ex_autosomes_senegal_SM_V7_4.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --out results/ld/smv7_ex_autosomes_senegal_SM_V7_4
#   --recode 12
#   --threads 6
#   --vcf results/ld/smv7_ex_autosomes_senegal_SM_V7_4.vcf
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# --vcf: results/ld/smv7_ex_autosomes_senegal_SM_V7_4-temporary.bed +
# results/ld/smv7_ex_autosomes_senegal_SM_V7_4-temporary.bim +
# results/ld/smv7_ex_autosomes_senegal_SM_V7_4-temporary.fam written.
# 1700 variants loaded from .bim file.
# 25 people (0 males, 0 females, 25 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to results/ld/smv7_ex_autosomes_senegal_SM_V7_4.nosex
# .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 25 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.864494.
# 1700 variants and 25 people pass filters and QC.
# Note: No phenotypes present.
# --recode ped to results/ld/smv7_ex_autosomes_senegal_SM_V7_4.ped +
# results/ld/smv7_ex_autosomes_senegal_SM_V7_4.map ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to results/ld/smv7_ex_autosomes_senegal_SM_V7_4.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --file results/ld/smv7_ex_autosomes_senegal_SM_V7_4
#   --ld-window 1000000
#   --ld-window-kb 1000
#   --ld-window-r2 0.0
#   --out results/ld/smv7_ex_autosomes_senegal_SM_V7_4
#   --r2
#   --threads 6
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# .ped scan complete (for binary autoconversion).0646872768084889296100%
# Performing single-pass .bed write (1700 variants, 25 people).
# --file: results/ld/smv7_ex_autosomes_senegal_SM_V7_4-temporary.bed +444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394%
# results/ld/smv7_ex_autosomes_senegal_SM_V7_4-temporary.bim +
# results/ld/smv7_ex_autosomes_senegal_SM_V7_4-temporary.fam written.
# 1700 variants loaded from .bim file.
# 25 people (0 males, 0 females, 25 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to results/ld/smv7_ex_autosomes_senegal_SM_V7_4.nosex
# .
# Using up to 6 threads (change this with --threads).
# Before main variant filters, 25 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.864494.
# 1700 variants and 25 people pass filters and QC.
# Note: No phenotypes present.
# --r2 to results/ld/smv7_ex_autosomes_senegal_SM_V7_4.ld ... 0% [processingwriting]        done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Note: --recode12 flag deprecated.  Use "--recode 12 ...".
# Logging to results/ld/smv7_ex_autosomes_senegal_SM_V7_5.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --out results/ld/smv7_ex_autosomes_senegal_SM_V7_5
#   --recode 12
#   --threads 6
#   --vcf results/ld/smv7_ex_autosomes_senegal_SM_V7_5.vcf
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# --vcf: results/ld/smv7_ex_autosomes_senegal_SM_V7_5-temporary.bed +
# results/ld/smv7_ex_autosomes_senegal_SM_V7_5-temporary.bim +
# results/ld/smv7_ex_autosomes_senegal_SM_V7_5-temporary.fam written.
# 1177 variants loaded from .bim file.
# 25 people (0 males, 0 females, 25 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to results/ld/smv7_ex_autosomes_senegal_SM_V7_5.nosex
# .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 25 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.851215.
# 1177 variants and 25 people pass filters and QC.
# Note: No phenotypes present.
# --recode ped to results/ld/smv7_ex_autosomes_senegal_SM_V7_5.ped +
# results/ld/smv7_ex_autosomes_senegal_SM_V7_5.map ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to results/ld/smv7_ex_autosomes_senegal_SM_V7_5.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --file results/ld/smv7_ex_autosomes_senegal_SM_V7_5
#   --ld-window 1000000
#   --ld-window-kb 1000
#   --ld-window-r2 0.0
#   --out results/ld/smv7_ex_autosomes_senegal_SM_V7_5
#   --r2
#   --threads 6
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# .ped scan complete (for binary autoconversion).0646872768084889296100%
# Performing single-pass .bed write (1177 variants, 25 people).
# --file: results/ld/smv7_ex_autosomes_senegal_SM_V7_5-temporary.bed +444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394%
# results/ld/smv7_ex_autosomes_senegal_SM_V7_5-temporary.bim +
# results/ld/smv7_ex_autosomes_senegal_SM_V7_5-temporary.fam written.
# 1177 variants loaded from .bim file.
# 25 people (0 males, 0 females, 25 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to results/ld/smv7_ex_autosomes_senegal_SM_V7_5.nosex
# .
# Using up to 6 threads (change this with --threads).
# Before main variant filters, 25 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.851215.
# 1177 variants and 25 people pass filters and QC.
# Note: No phenotypes present.
# --r2 to results/ld/smv7_ex_autosomes_senegal_SM_V7_5.ld ... 0% [processingwriting]        done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Note: --recode12 flag deprecated.  Use "--recode 12 ...".
# Logging to results/ld/smv7_ex_autosomes_senegal_SM_V7_6.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --out results/ld/smv7_ex_autosomes_senegal_SM_V7_6
#   --recode 12
#   --threads 6
#   --vcf results/ld/smv7_ex_autosomes_senegal_SM_V7_6.vcf
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# --vcf: results/ld/smv7_ex_autosomes_senegal_SM_V7_6-temporary.bed +
# results/ld/smv7_ex_autosomes_senegal_SM_V7_6-temporary.bim +
# results/ld/smv7_ex_autosomes_senegal_SM_V7_6-temporary.fam written.
# 1048 variants loaded from .bim file.
# 25 people (0 males, 0 females, 25 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to results/ld/smv7_ex_autosomes_senegal_SM_V7_6.nosex
# .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 25 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.851069.
# 1048 variants and 25 people pass filters and QC.
# Note: No phenotypes present.
# --recode ped to results/ld/smv7_ex_autosomes_senegal_SM_V7_6.ped +
# results/ld/smv7_ex_autosomes_senegal_SM_V7_6.map ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to results/ld/smv7_ex_autosomes_senegal_SM_V7_6.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --file results/ld/smv7_ex_autosomes_senegal_SM_V7_6
#   --ld-window 1000000
#   --ld-window-kb 1000
#   --ld-window-r2 0.0
#   --out results/ld/smv7_ex_autosomes_senegal_SM_V7_6
#   --r2
#   --threads 6
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# .ped scan complete (for binary autoconversion).0646872768084889296100%
# Performing single-pass .bed write (1048 variants, 25 people).
# --file: results/ld/smv7_ex_autosomes_senegal_SM_V7_6-temporary.bed +444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394%
# results/ld/smv7_ex_autosomes_senegal_SM_V7_6-temporary.bim +
# results/ld/smv7_ex_autosomes_senegal_SM_V7_6-temporary.fam written.
# 1048 variants loaded from .bim file.
# 25 people (0 males, 0 females, 25 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to results/ld/smv7_ex_autosomes_senegal_SM_V7_6.nosex
# .
# Using up to 6 threads (change this with --threads).
# Before main variant filters, 25 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.851069.
# 1048 variants and 25 people pass filters and QC.
# Note: No phenotypes present.
# --r2 to results/ld/smv7_ex_autosomes_senegal_SM_V7_6.ld ... 0% [processingwriting]        done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Note: --recode12 flag deprecated.  Use "--recode 12 ...".
# Logging to results/ld/smv7_ex_autosomes_senegal_SM_V7_7.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --out results/ld/smv7_ex_autosomes_senegal_SM_V7_7
#   --recode 12
#   --threads 6
#   --vcf results/ld/smv7_ex_autosomes_senegal_SM_V7_7.vcf
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# --vcf: results/ld/smv7_ex_autosomes_senegal_SM_V7_7-temporary.bed +
# results/ld/smv7_ex_autosomes_senegal_SM_V7_7-temporary.bim +
# results/ld/smv7_ex_autosomes_senegal_SM_V7_7-temporary.fam written.
# 605 variants loaded from .bim file.
# 25 people (0 males, 0 females, 25 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to results/ld/smv7_ex_autosomes_senegal_SM_V7_7.nosex
# .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 25 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.850975.
# 605 variants and 25 people pass filters and QC.
# Note: No phenotypes present.
# --recode ped to results/ld/smv7_ex_autosomes_senegal_SM_V7_7.ped +
# results/ld/smv7_ex_autosomes_senegal_SM_V7_7.map ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to results/ld/smv7_ex_autosomes_senegal_SM_V7_7.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --file results/ld/smv7_ex_autosomes_senegal_SM_V7_7
#   --ld-window 1000000
#   --ld-window-kb 1000
#   --ld-window-r2 0.0
#   --out results/ld/smv7_ex_autosomes_senegal_SM_V7_7
#   --r2
#   --threads 6
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# .ped scan complete (for binary autoconversion).0646872768084889296100%
# Performing single-pass .bed write (605 variants, 25 people).
# --file: results/ld/smv7_ex_autosomes_senegal_SM_V7_7-temporary.bed +444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394%
# results/ld/smv7_ex_autosomes_senegal_SM_V7_7-temporary.bim +
# results/ld/smv7_ex_autosomes_senegal_SM_V7_7-temporary.fam written.
# 605 variants loaded from .bim file.
# 25 people (0 males, 0 females, 25 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to results/ld/smv7_ex_autosomes_senegal_SM_V7_7.nosex
# .
# Using up to 6 threads (change this with --threads).
# Before main variant filters, 25 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.850975.
# 605 variants and 25 people pass filters and QC.
# Note: No phenotypes present.
# --r2 to results/ld/smv7_ex_autosomes_senegal_SM_V7_7.ld ... 0% [processingwriting]        done.
# niger
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Note: --recode12 flag deprecated.  Use "--recode 12 ...".
# Logging to results/ld/smv7_ex_autosomes_niger_SM_V7_1.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --out results/ld/smv7_ex_autosomes_niger_SM_V7_1
#   --recode 12
#   --threads 6
#   --vcf results/ld/smv7_ex_autosomes_niger_SM_V7_1.vcf
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# --vcf: results/ld/smv7_ex_autosomes_niger_SM_V7_1-temporary.bed +
# results/ld/smv7_ex_autosomes_niger_SM_V7_1-temporary.bim +
# results/ld/smv7_ex_autosomes_niger_SM_V7_1-temporary.fam written.
# 6120 variants loaded from .bim file.
# 10 people (0 males, 0 females, 10 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to results/ld/smv7_ex_autosomes_niger_SM_V7_1.nosex .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 10 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.864118.
# 6120 variants and 10 people pass filters and QC.
# Note: No phenotypes present.
# --recode ped to results/ld/smv7_ex_autosomes_niger_SM_V7_1.ped +
# results/ld/smv7_ex_autosomes_niger_SM_V7_1.map ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to results/ld/smv7_ex_autosomes_niger_SM_V7_1.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --file results/ld/smv7_ex_autosomes_niger_SM_V7_1
#   --ld-window 1000000
#   --ld-window-kb 1000
#   --ld-window-r2 0.0
#   --out results/ld/smv7_ex_autosomes_niger_SM_V7_1
#   --r2
#   --threads 6
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# .ped scan complete (for binary autoconversion).
# Performing single-pass .bed write (6120 variants, 10 people).
# --file: results/ld/smv7_ex_autosomes_niger_SM_V7_1-temporary.bed +43444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394%
# results/ld/smv7_ex_autosomes_niger_SM_V7_1-temporary.bim +
# results/ld/smv7_ex_autosomes_niger_SM_V7_1-temporary.fam written.
# 6120 variants loaded from .bim file.
# 10 people (0 males, 0 females, 10 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to results/ld/smv7_ex_autosomes_niger_SM_V7_1.nosex .
# Using up to 6 threads (change this with --threads).
# Before main variant filters, 10 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.864118.
# 6120 variants and 10 people pass filters and QC.
# Note: No phenotypes present.
# --r2 to results/ld/smv7_ex_autosomes_niger_SM_V7_1.ld ... 0% [processingwriting]        done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Note: --recode12 flag deprecated.  Use "--recode 12 ...".
# Logging to results/ld/smv7_ex_autosomes_niger_SM_V7_2.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --out results/ld/smv7_ex_autosomes_niger_SM_V7_2
#   --recode 12
#   --threads 6
#   --vcf results/ld/smv7_ex_autosomes_niger_SM_V7_2.vcf
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# --vcf: results/ld/smv7_ex_autosomes_niger_SM_V7_2-temporary.bed +
# results/ld/smv7_ex_autosomes_niger_SM_V7_2-temporary.bim +
# results/ld/smv7_ex_autosomes_niger_SM_V7_2-temporary.fam written.
# 4661 variants loaded from .bim file.
# 10 people (0 males, 0 females, 10 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to results/ld/smv7_ex_autosomes_niger_SM_V7_2.nosex .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 10 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.832868.
# 4661 variants and 10 people pass filters and QC.
# Note: No phenotypes present.
# --recode ped to results/ld/smv7_ex_autosomes_niger_SM_V7_2.ped +
# results/ld/smv7_ex_autosomes_niger_SM_V7_2.map ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to results/ld/smv7_ex_autosomes_niger_SM_V7_2.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --file results/ld/smv7_ex_autosomes_niger_SM_V7_2
#   --ld-window 1000000
#   --ld-window-kb 1000
#   --ld-window-r2 0.0
#   --out results/ld/smv7_ex_autosomes_niger_SM_V7_2
#   --r2
#   --threads 6
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# .ped scan complete (for binary autoconversion).
# Performing single-pass .bed write (4661 variants, 10 people).
# --file: results/ld/smv7_ex_autosomes_niger_SM_V7_2-temporary.bed +43444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394%
# results/ld/smv7_ex_autosomes_niger_SM_V7_2-temporary.bim +
# results/ld/smv7_ex_autosomes_niger_SM_V7_2-temporary.fam written.
# 4661 variants loaded from .bim file.
# 10 people (0 males, 0 females, 10 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to results/ld/smv7_ex_autosomes_niger_SM_V7_2.nosex .
# Using up to 6 threads (change this with --threads).
# Before main variant filters, 10 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.832868.
# 4661 variants and 10 people pass filters and QC.
# Note: No phenotypes present.
# --r2 to results/ld/smv7_ex_autosomes_niger_SM_V7_2.ld ... 0% [processingwriting]        done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Note: --recode12 flag deprecated.  Use "--recode 12 ...".
# Logging to results/ld/smv7_ex_autosomes_niger_SM_V7_3.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --out results/ld/smv7_ex_autosomes_niger_SM_V7_3
#   --recode 12
#   --threads 6
#   --vcf results/ld/smv7_ex_autosomes_niger_SM_V7_3.vcf
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# --vcf: results/ld/smv7_ex_autosomes_niger_SM_V7_3-temporary.bed +
# results/ld/smv7_ex_autosomes_niger_SM_V7_3-temporary.bim +
# results/ld/smv7_ex_autosomes_niger_SM_V7_3-temporary.fam written.
# 4573 variants loaded from .bim file.
# 10 people (0 males, 0 females, 10 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to results/ld/smv7_ex_autosomes_niger_SM_V7_3.nosex .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 10 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.848786.
# 4573 variants and 10 people pass filters and QC.
# Note: No phenotypes present.
# --recode ped to results/ld/smv7_ex_autosomes_niger_SM_V7_3.ped +
# results/ld/smv7_ex_autosomes_niger_SM_V7_3.map ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to results/ld/smv7_ex_autosomes_niger_SM_V7_3.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --file results/ld/smv7_ex_autosomes_niger_SM_V7_3
#   --ld-window 1000000
#   --ld-window-kb 1000
#   --ld-window-r2 0.0
#   --out results/ld/smv7_ex_autosomes_niger_SM_V7_3
#   --r2
#   --threads 6
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# .ped scan complete (for binary autoconversion).
# Performing single-pass .bed write (4573 variants, 10 people).
# --file: results/ld/smv7_ex_autosomes_niger_SM_V7_3-temporary.bed +43444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394%
# results/ld/smv7_ex_autosomes_niger_SM_V7_3-temporary.bim +
# results/ld/smv7_ex_autosomes_niger_SM_V7_3-temporary.fam written.
# 4573 variants loaded from .bim file.
# 10 people (0 males, 0 females, 10 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to results/ld/smv7_ex_autosomes_niger_SM_V7_3.nosex .
# Using up to 6 threads (change this with --threads).
# Before main variant filters, 10 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.848786.
# 4573 variants and 10 people pass filters and QC.
# Note: No phenotypes present.
# --r2 to results/ld/smv7_ex_autosomes_niger_SM_V7_3.ld ... 0% [processingwriting]        done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Note: --recode12 flag deprecated.  Use "--recode 12 ...".
# Logging to results/ld/smv7_ex_autosomes_niger_SM_V7_4.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --out results/ld/smv7_ex_autosomes_niger_SM_V7_4
#   --recode 12
#   --threads 6
#   --vcf results/ld/smv7_ex_autosomes_niger_SM_V7_4.vcf
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# --vcf: results/ld/smv7_ex_autosomes_niger_SM_V7_4-temporary.bed +
# results/ld/smv7_ex_autosomes_niger_SM_V7_4-temporary.bim +
# results/ld/smv7_ex_autosomes_niger_SM_V7_4-temporary.fam written.
# 3253 variants loaded from .bim file.
# 10 people (0 males, 0 females, 10 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to results/ld/smv7_ex_autosomes_niger_SM_V7_4.nosex .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 10 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.845773.
# 3253 variants and 10 people pass filters and QC.
# Note: No phenotypes present.
# --recode ped to results/ld/smv7_ex_autosomes_niger_SM_V7_4.ped +
# results/ld/smv7_ex_autosomes_niger_SM_V7_4.map ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to results/ld/smv7_ex_autosomes_niger_SM_V7_4.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --file results/ld/smv7_ex_autosomes_niger_SM_V7_4
#   --ld-window 1000000
#   --ld-window-kb 1000
#   --ld-window-r2 0.0
#   --out results/ld/smv7_ex_autosomes_niger_SM_V7_4
#   --r2
#   --threads 6
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# .ped scan complete (for binary autoconversion).
# Performing single-pass .bed write (3253 variants, 10 people).
# --file: results/ld/smv7_ex_autosomes_niger_SM_V7_4-temporary.bed +43444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394%
# results/ld/smv7_ex_autosomes_niger_SM_V7_4-temporary.bim +
# results/ld/smv7_ex_autosomes_niger_SM_V7_4-temporary.fam written.
# 3253 variants loaded from .bim file.
# 10 people (0 males, 0 females, 10 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to results/ld/smv7_ex_autosomes_niger_SM_V7_4.nosex .
# Using up to 6 threads (change this with --threads).
# Before main variant filters, 10 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.845773.
# 3253 variants and 10 people pass filters and QC.
# Note: No phenotypes present.
# --r2 to results/ld/smv7_ex_autosomes_niger_SM_V7_4.ld ... 0% [processingwriting]        done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Note: --recode12 flag deprecated.  Use "--recode 12 ...".
# Logging to results/ld/smv7_ex_autosomes_niger_SM_V7_5.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --out results/ld/smv7_ex_autosomes_niger_SM_V7_5
#   --recode 12
#   --threads 6
#   --vcf results/ld/smv7_ex_autosomes_niger_SM_V7_5.vcf
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# --vcf: results/ld/smv7_ex_autosomes_niger_SM_V7_5-temporary.bed +
# results/ld/smv7_ex_autosomes_niger_SM_V7_5-temporary.bim +
# results/ld/smv7_ex_autosomes_niger_SM_V7_5-temporary.fam written.
# 2138 variants loaded from .bim file.
# 10 people (0 males, 0 females, 10 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to results/ld/smv7_ex_autosomes_niger_SM_V7_5.nosex .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 10 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.826099.
# 2138 variants and 10 people pass filters and QC.
# Note: No phenotypes present.
# --recode ped to results/ld/smv7_ex_autosomes_niger_SM_V7_5.ped +
# results/ld/smv7_ex_autosomes_niger_SM_V7_5.map ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to results/ld/smv7_ex_autosomes_niger_SM_V7_5.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --file results/ld/smv7_ex_autosomes_niger_SM_V7_5
#   --ld-window 1000000
#   --ld-window-kb 1000
#   --ld-window-r2 0.0
#   --out results/ld/smv7_ex_autosomes_niger_SM_V7_5
#   --r2
#   --threads 6
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# .ped scan complete (for binary autoconversion).
# Performing single-pass .bed write (2138 variants, 10 people).
# --file: results/ld/smv7_ex_autosomes_niger_SM_V7_5-temporary.bed +43444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394%
# results/ld/smv7_ex_autosomes_niger_SM_V7_5-temporary.bim +
# results/ld/smv7_ex_autosomes_niger_SM_V7_5-temporary.fam written.
# 2138 variants loaded from .bim file.
# 10 people (0 males, 0 females, 10 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to results/ld/smv7_ex_autosomes_niger_SM_V7_5.nosex .
# Using up to 6 threads (change this with --threads).
# Before main variant filters, 10 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.826099.
# 2138 variants and 10 people pass filters and QC.
# Note: No phenotypes present.
# --r2 to results/ld/smv7_ex_autosomes_niger_SM_V7_5.ld ... 0% [processingwriting]        done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Note: --recode12 flag deprecated.  Use "--recode 12 ...".
# Logging to results/ld/smv7_ex_autosomes_niger_SM_V7_6.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --out results/ld/smv7_ex_autosomes_niger_SM_V7_6
#   --recode 12
#   --threads 6
#   --vcf results/ld/smv7_ex_autosomes_niger_SM_V7_6.vcf
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# --vcf: results/ld/smv7_ex_autosomes_niger_SM_V7_6-temporary.bed +
# results/ld/smv7_ex_autosomes_niger_SM_V7_6-temporary.bim +
# results/ld/smv7_ex_autosomes_niger_SM_V7_6-temporary.fam written.
# 2044 variants loaded from .bim file.
# 10 people (0 males, 0 females, 10 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to results/ld/smv7_ex_autosomes_niger_SM_V7_6.nosex .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 10 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.812231.
# 2044 variants and 10 people pass filters and QC.
# Note: No phenotypes present.
# --recode ped to results/ld/smv7_ex_autosomes_niger_SM_V7_6.ped +
# results/ld/smv7_ex_autosomes_niger_SM_V7_6.map ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to results/ld/smv7_ex_autosomes_niger_SM_V7_6.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --file results/ld/smv7_ex_autosomes_niger_SM_V7_6
#   --ld-window 1000000
#   --ld-window-kb 1000
#   --ld-window-r2 0.0
#   --out results/ld/smv7_ex_autosomes_niger_SM_V7_6
#   --r2
#   --threads 6
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# .ped scan complete (for binary autoconversion).
# Performing single-pass .bed write (2044 variants, 10 people).
# --file: results/ld/smv7_ex_autosomes_niger_SM_V7_6-temporary.bed +43444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394%
# results/ld/smv7_ex_autosomes_niger_SM_V7_6-temporary.bim +
# results/ld/smv7_ex_autosomes_niger_SM_V7_6-temporary.fam written.
# 2044 variants loaded from .bim file.
# 10 people (0 males, 0 females, 10 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to results/ld/smv7_ex_autosomes_niger_SM_V7_6.nosex .
# Using up to 6 threads (change this with --threads).
# Before main variant filters, 10 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.812231.
# 2044 variants and 10 people pass filters and QC.
# Note: No phenotypes present.
# --r2 to results/ld/smv7_ex_autosomes_niger_SM_V7_6.ld ... 0% [processingwriting]        done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Note: --recode12 flag deprecated.  Use "--recode 12 ...".
# Logging to results/ld/smv7_ex_autosomes_niger_SM_V7_7.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --out results/ld/smv7_ex_autosomes_niger_SM_V7_7
#   --recode 12
#   --threads 6
#   --vcf results/ld/smv7_ex_autosomes_niger_SM_V7_7.vcf
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# --vcf: results/ld/smv7_ex_autosomes_niger_SM_V7_7-temporary.bed +
# results/ld/smv7_ex_autosomes_niger_SM_V7_7-temporary.bim +
# results/ld/smv7_ex_autosomes_niger_SM_V7_7-temporary.fam written.
# 1259 variants loaded from .bim file.
# 10 people (0 males, 0 females, 10 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to results/ld/smv7_ex_autosomes_niger_SM_V7_7.nosex .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 10 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.82645.
# 1259 variants and 10 people pass filters and QC.
# Note: No phenotypes present.
# --recode ped to results/ld/smv7_ex_autosomes_niger_SM_V7_7.ped +
# results/ld/smv7_ex_autosomes_niger_SM_V7_7.map ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to results/ld/smv7_ex_autosomes_niger_SM_V7_7.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --file results/ld/smv7_ex_autosomes_niger_SM_V7_7
#   --ld-window 1000000
#   --ld-window-kb 1000
#   --ld-window-r2 0.0
#   --out results/ld/smv7_ex_autosomes_niger_SM_V7_7
#   --r2
#   --threads 6
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# .ped scan complete (for binary autoconversion).
# Performing single-pass .bed write (1259 variants, 10 people).
# --file: results/ld/smv7_ex_autosomes_niger_SM_V7_7-temporary.bed +43444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394%
# results/ld/smv7_ex_autosomes_niger_SM_V7_7-temporary.bim +
# results/ld/smv7_ex_autosomes_niger_SM_V7_7-temporary.fam written.
# 1259 variants loaded from .bim file.
# 10 people (0 males, 0 females, 10 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to results/ld/smv7_ex_autosomes_niger_SM_V7_7.nosex .
# Using up to 6 threads (change this with --threads).
# Before main variant filters, 10 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.82645.
# 1259 variants and 10 people pass filters and QC.
# Note: No phenotypes present.
# --r2 to results/ld/smv7_ex_autosomes_niger_SM_V7_7.ld ... 0% [processingwriting]        done.
# brazil
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Note: --recode12 flag deprecated.  Use "--recode 12 ...".
# Logging to results/ld/smv7_ex_autosomes_brazil_SM_V7_1.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --out results/ld/smv7_ex_autosomes_brazil_SM_V7_1
#   --recode 12
#   --threads 6
#   --vcf results/ld/smv7_ex_autosomes_brazil_SM_V7_1.vcf
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# --vcf: results/ld/smv7_ex_autosomes_brazil_SM_V7_1-temporary.bed +
# results/ld/smv7_ex_autosomes_brazil_SM_V7_1-temporary.bim +
# results/ld/smv7_ex_autosomes_brazil_SM_V7_1-temporary.fam written.
# 5337 variants loaded from .bim file.
# 45 people (0 males, 0 females, 45 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to results/ld/smv7_ex_autosomes_brazil_SM_V7_1.nosex
# .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 45 founders and 0 nonfounders present.
# ...
# Total genotyping rate is 0.806714.
# 7355 variants and 55 people pass filters and QC.
# Note: No phenotypes present.
# --recode ped to results/ld/smv7_ex_autosomes_tanzania_SM_V7_3.ped +
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_3.map ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to results/ld/smv7_ex_autosomes_tanzania_SM_V7_3.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --file results/ld/smv7_ex_autosomes_tanzania_SM_V7_3
#   --ld-window 1000000
#   --ld-window-kb 1000
#   --ld-window-r2 0.0
#   --out results/ld/smv7_ex_autosomes_tanzania_SM_V7_3
#   --r2
#   --threads 6
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# .ped scan complete (for binary autoconversion).2343638404143454749505254565860616365676970727476788081838587899092949698100%
# Performing single-pass .bed write (7355 variants, 55 people).
# --file: results/ld/smv7_ex_autosomes_tanzania_SM_V7_3-temporary.bed +44546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394%
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_3-temporary.bim +
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_3-temporary.fam written.
# 7355 variants loaded from .bim file.
# 55 people (0 males, 0 females, 55 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_3.nosex .
# Using up to 6 threads (change this with --threads).
# Before main variant filters, 55 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.806714.
# 7355 variants and 55 people pass filters and QC.
# Note: No phenotypes present.
# --r2 to results/ld/smv7_ex_autosomes_tanzania_SM_V7_3.ld ... 0% [processingwriting]        done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Note: --recode12 flag deprecated.  Use "--recode 12 ...".
# Logging to results/ld/smv7_ex_autosomes_tanzania_SM_V7_4.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --out results/ld/smv7_ex_autosomes_tanzania_SM_V7_4
#   --recode 12
#   --threads 6
#   --vcf results/ld/smv7_ex_autosomes_tanzania_SM_V7_4.vcf
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# --vcf: results/ld/smv7_ex_autosomes_tanzania_SM_V7_4-temporary.bed +
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_4-temporary.bim +
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_4-temporary.fam written.
# 6818 variants loaded from .bim file.
# 55 people (0 males, 0 females, 55 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_4.nosex .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 55 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.806424.
# 6818 variants and 55 people pass filters and QC.
# Note: No phenotypes present.
# --recode ped to results/ld/smv7_ex_autosomes_tanzania_SM_V7_4.ped +
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_4.map ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to results/ld/smv7_ex_autosomes_tanzania_SM_V7_4.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --file results/ld/smv7_ex_autosomes_tanzania_SM_V7_4
#   --ld-window 1000000
#   --ld-window-kb 1000
#   --ld-window-r2 0.0
#   --out results/ld/smv7_ex_autosomes_tanzania_SM_V7_4
#   --r2
#   --threads 6
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# .ped scan complete (for binary autoconversion).2343638404143454749505254565860616365676970727476788081838587899092949698100%
# Performing single-pass .bed write (6818 variants, 55 people).
# --file: results/ld/smv7_ex_autosomes_tanzania_SM_V7_4-temporary.bed +44546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394%
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_4-temporary.bim +
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_4-temporary.fam written.
# 6818 variants loaded from .bim file.
# 55 people (0 males, 0 females, 55 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_4.nosex .
# Using up to 6 threads (change this with --threads).
# Before main variant filters, 55 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.806424.
# 6818 variants and 55 people pass filters and QC.
# Note: No phenotypes present.
# --r2 to results/ld/smv7_ex_autosomes_tanzania_SM_V7_4.ld ... 0% [processingwriting]        done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Note: --recode12 flag deprecated.  Use "--recode 12 ...".
# Logging to results/ld/smv7_ex_autosomes_tanzania_SM_V7_5.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --out results/ld/smv7_ex_autosomes_tanzania_SM_V7_5
#   --recode 12
#   --threads 6
#   --vcf results/ld/smv7_ex_autosomes_tanzania_SM_V7_5.vcf
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# --vcf: results/ld/smv7_ex_autosomes_tanzania_SM_V7_5-temporary.bed +
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_5-temporary.bim +
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_5-temporary.fam written.
# 3148 variants loaded from .bim file.
# 55 people (0 males, 0 females, 55 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_5.nosex .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 55 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.78585.
# 3148 variants and 55 people pass filters and QC.
# Note: No phenotypes present.
# --recode ped to results/ld/smv7_ex_autosomes_tanzania_SM_V7_5.ped +
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_5.map ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to results/ld/smv7_ex_autosomes_tanzania_SM_V7_5.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --file results/ld/smv7_ex_autosomes_tanzania_SM_V7_5
#   --ld-window 1000000
#   --ld-window-kb 1000
#   --ld-window-r2 0.0
#   --out results/ld/smv7_ex_autosomes_tanzania_SM_V7_5
#   --r2
#   --threads 6
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# .ped scan complete (for binary autoconversion).2343638404143454749505254565860616365676970727476788081838587899092949698100%
# Performing single-pass .bed write (3148 variants, 55 people).
# --file: results/ld/smv7_ex_autosomes_tanzania_SM_V7_5-temporary.bed +44546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394%
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_5-temporary.bim +
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_5-temporary.fam written.
# 3148 variants loaded from .bim file.
# 55 people (0 males, 0 females, 55 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_5.nosex .
# Using up to 6 threads (change this with --threads).
# Before main variant filters, 55 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.78585.
# 3148 variants and 55 people pass filters and QC.
# Note: No phenotypes present.
# --r2 to results/ld/smv7_ex_autosomes_tanzania_SM_V7_5.ld ... 0% [processingwriting]        done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Note: --recode12 flag deprecated.  Use "--recode 12 ...".
# Logging to results/ld/smv7_ex_autosomes_tanzania_SM_V7_6.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --out results/ld/smv7_ex_autosomes_tanzania_SM_V7_6
#   --recode 12
#   --threads 6
#   --vcf results/ld/smv7_ex_autosomes_tanzania_SM_V7_6.vcf
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# --vcf: results/ld/smv7_ex_autosomes_tanzania_SM_V7_6-temporary.bed +
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_6-temporary.bim +
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_6-temporary.fam written.
# 3324 variants loaded from .bim file.
# 55 people (0 males, 0 females, 55 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_6.nosex .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 55 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.784805.
# 3324 variants and 55 people pass filters and QC.
# Note: No phenotypes present.
# --recode ped to results/ld/smv7_ex_autosomes_tanzania_SM_V7_6.ped +
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_6.map ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to results/ld/smv7_ex_autosomes_tanzania_SM_V7_6.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --file results/ld/smv7_ex_autosomes_tanzania_SM_V7_6
#   --ld-window 1000000
#   --ld-window-kb 1000
#   --ld-window-r2 0.0
#   --out results/ld/smv7_ex_autosomes_tanzania_SM_V7_6
#   --r2
#   --threads 6
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# .ped scan complete (for binary autoconversion).2343638404143454749505254565860616365676970727476788081838587899092949698100%
# Performing single-pass .bed write (3324 variants, 55 people).
# --file: results/ld/smv7_ex_autosomes_tanzania_SM_V7_6-temporary.bed +44546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394%
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_6-temporary.bim +
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_6-temporary.fam written.
# 3324 variants loaded from .bim file.
# 55 people (0 males, 0 females, 55 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_6.nosex .
# Using up to 6 threads (change this with --threads).
# Before main variant filters, 55 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.784805.
# 3324 variants and 55 people pass filters and QC.
# Note: No phenotypes present.
# --r2 to results/ld/smv7_ex_autosomes_tanzania_SM_V7_6.ld ... 0% [processingwriting]        done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Note: --recode12 flag deprecated.  Use "--recode 12 ...".
# Logging to results/ld/smv7_ex_autosomes_tanzania_SM_V7_7.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --out results/ld/smv7_ex_autosomes_tanzania_SM_V7_7
#   --recode 12
#   --threads 6
#   --vcf results/ld/smv7_ex_autosomes_tanzania_SM_V7_7.vcf
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# --vcf: results/ld/smv7_ex_autosomes_tanzania_SM_V7_7-temporary.bed +
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_7-temporary.bim +
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_7-temporary.fam written.
# 2574 variants loaded from .bim file.
# 55 people (0 males, 0 females, 55 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_7.nosex .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 55 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.787985.
# 2574 variants and 55 people pass filters and QC.
# Note: No phenotypes present.
# --recode ped to results/ld/smv7_ex_autosomes_tanzania_SM_V7_7.ped +
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_7.map ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to results/ld/smv7_ex_autosomes_tanzania_SM_V7_7.log.
# Options in effect:
#   --allow-extra-chr
#   --double-id
#   --file results/ld/smv7_ex_autosomes_tanzania_SM_V7_7
#   --ld-window 1000000
#   --ld-window-kb 1000
#   --ld-window-r2 0.0
#   --out results/ld/smv7_ex_autosomes_tanzania_SM_V7_7
#   --r2
#   --threads 6
#
# 128540 MB RAM detected; reserving 64270 MB for main workspace.
# .ped scan complete (for binary autoconversion).2343638404143454749505254565860616365676970727476788081838587899092949698100%
# Performing single-pass .bed write (2574 variants, 55 people).
# --file: results/ld/smv7_ex_autosomes_tanzania_SM_V7_7-temporary.bed +44546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394%
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_7-temporary.bim +
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_7-temporary.fam written.
# 2574 variants loaded from .bim file.
# 55 people (0 males, 0 females, 55 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# results/ld/smv7_ex_autosomes_tanzania_SM_V7_7.nosex .
# Using up to 6 threads (change this with --threads).
# Before main variant filters, 55 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.787985.
# 2574 variants and 55 people pass filters and QC.
# Note: No phenotypes present.
# --r2 to results/ld/smv7_ex_autosomes_tanzania_SM_V7_7.ld ... 0% [processingwriting]        done.

# %% [markdown]
# Make new files that contain all R2 info from Plink, but also add distance between SNP-A and SNP-B.

# %%
#create tables
for pop in ["senegal", "niger", "brazil", "tanzania"]:
    print(pop)
    
    in_list = "results/ld/{}.list".format(pop)
    
    #open the outfile that will contain ALL of the data (and add a header)
    with open("results/ld/smv7_ex_autosomes_{}_dist.tbl".format(pop), 'w') as merged_all_out_file:
        #print header line
        header_line="chr_a\tbp_a\tsnp_a\tchr_b\tbp_b\tsnp_b\tr2\ta_b_dist\n"
        merged_all_out_file.write(header_line)
        
        #open each chrom specific ld file (and skip the header)
        for chrom in list(range(1, 8)):
            chrom="SM_V7_{}".format(chrom)
            plink_file="results/ld/smv7_ex_autosomes_{}_{}.ld".format(pop, chrom)

            with open(plink_file, 'r') as in_file:
                next(in_file)

                #for each r2 calc
                for entry in in_file:
                    entry=','.join(entry.split())
                    chr_a, bp_a, snp_a, chr_b, bp_b, snp_b, r2 = entry.split(",")

                    #calculate the distance between the snps
                    a_b_dist = int(bp_b) - int(bp_a)
                    outline=[chr_a, bp_a, snp_a, chr_b, bp_b, snp_b, r2, str(a_b_dist), "\n"]
                    outline="\t".join(outline)

                    #and print to the ALL output file
                    merged_all_out_file.write(outline)
# Out:
# senegal
# niger
# brazil
# tanzania

# %%
#clean up all of the unused files
for pop in ["senegal", "niger", "brazil", "tanzania"]:
    for chrom in list(range(1, 8)):
        chrom="SM_V7_{}".format(chrom)
        for ext in ["ld", "map", "ped", "log", "nosex", "vcf"]:
            file_to_del="results/ld/smv7_ex_autosomes_{}_{}.{}".format(pop, chrom, ext)
            if os.path.exists(file_to_del):
                os.remove(file_to_del)

# %% [markdown]
# ## Calc. mean R2 values per bin/distance

# %%
#read in plink R2 data and create a df to save
dists=defaultdict(lambda: list())
r2s=defaultdict(lambda: list())

for pop in ["niger", "senegal", "brazil", "tanzania"]:
    print(pop)

    with open("results/ld/smv7_ex_autosomes_{}_dist.tbl".format(pop), 'r') as in_file:
        #skip header line
        next(in_file)

        for entry in in_file:
            chr_a, bp_a, snp_a, chr_b, bp_b, snp_b, r2, a_b_dist = entry.rstrip().split("\t")
            r2s[pop].append(float(r2))
            dists[pop].append(int(a_b_dist))

#convert to np array
for pop in ["niger", "senegal", "brazil", "tanzania"]:
    dists[pop]=np.array(dists[pop])
    r2s[pop]=np.array(r2s[pop])

    
#create bins for stat binning
bins=np.geomspace(1, 1_000_000, num=1000)

#get mean values for each bin
n, bin_edges, binnumber=stats.binned_statistic(dists["niger"], r2s["niger"], statistic='mean', bins=bins)
b, bin_edges, binnumber=stats.binned_statistic(dists["brazil"], r2s["brazil"], statistic='mean', bins=bins)
s, bin_edges, binnumber=stats.binned_statistic(dists["senegal"], r2s["senegal"], statistic='mean', bins=bins)
t, bin_edges, binnumber=stats.binned_statistic(dists["tanzania"], r2s["tanzania"], statistic='mean', bins=bins)

#save data to a csv for ease of access later
df=pd.DataFrame(data=[bin_edges[:-1], n, b, s, t]).T.dropna()
df.columns=["distance_bin", "niger_r2", "brazil_r2", "senegal_r2", "tanzania_r2"]
df.to_csv("results/ld/ld_dist_binned_smoothed_pybins.csv", sep=",")
# df
# Out:
# niger
# senegal
# brazil
# tanzania

# %%
plt.scatter(dists["niger"], r2s["niger"], s=3, c="red", label="Niger", alpha=0.002)
plt.xlabel("Distance (bp)")
plt.ylabel("R2")
plt.show()
plt.close()

# %% [markdown]
# # Plot

# %%
plt.scatter(df["distance_bin"], df["niger_r2"],    s=3, c="orange",    label="Niger")
plt.scatter(df["distance_bin"], df["senegal_r2"],  s=3, c="blue", label="Senegal")
plt.scatter(df["distance_bin"], df["tanzania_r2"], s=3, c="red",  label="Tanzania")
plt.scatter(df["distance_bin"], df["brazil_r2"],   s=3, c="green",   label="Brazil")
plt.xlabel("Distance (bp)")
plt.ylabel("R2")
#plt.xscale('log')
plt.ylim(0,1)
#plt.xlim(0,200_000)
#plt.legend(title="Populations (MAF=0.05)", markerscale=3)

#plt.savefig("results/ld/ld_decay_maf05.svg")
#plt.savefig("results/ld/ld_decay_maf05.png")

plt.show()
plt.close()

# %%
def ld(p1, q1):

    p1=float(p1)
    q1=float(q1)
    p2=1-p1
    q2=1-q1

    g11 = min([p1, q1])
    d=g11-(p1*q1)
    
    if d < 0:
        dp=d/(max(-p1*q1, -p2*q2))
    if d > 0:
        dp=d/(min(p1*q2, p2*q1))

    r2=d**2/(p1*p2*q1*q2)
    return d, dp, r2

# %%
for p1 in np.arange(.1,1,0.1):
    #for q1 in np.arange(.1,1,0.1):
    q1=0.3
    d, dp, r2 = ld(p1, q1)
    print("{:.2f}\t{:.2f}\t{:.2f}\t{:.2f}\t{:.2f}".format(d, dp, r2, p1, q1))
# Out:
# 0.07	1.00	0.26	0.10	0.30
# 0.14	1.00	0.58	0.20	0.30
# 0.21	1.00	1.00	0.30	0.30
# 0.18	1.00	0.64	0.40	0.30
# 0.15	1.00	0.43	0.50	0.30
# 0.12	1.00	0.29	0.60	0.30
# 0.09	1.00	0.18	0.70	0.30
# 0.06	1.00	0.11	0.80	0.30
# 0.03	1.00	0.05	0.90	0.30

# %%
p1
# Out:
# 0.0

# %%
r2
# Out:
# 0.25

# %%
p1=float(0.3)
q1=float(0.2)
p2=1-p1
q2=1-q1

g11 = min([p1, q1])
d=g11-(p1*q1)
r2=d**2/(p1*p2*q1*q2)

# %%
seq(0, 1, 0.1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_29258/2523566427.py in <module>
# ----> 1 seq(0, 1, 0.1)
#
# NameError: name 'seq' is not defined
